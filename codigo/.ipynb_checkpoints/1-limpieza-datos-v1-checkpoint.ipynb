# %% [markdown]
# ## Pre procesamiento de datos COVID-Peru
# ### Datos 'crudos' a datos 'pre procesados' listos para análisis
#
# Creado : 25th, Mayo <br>
# Ultima modificacion: 24th Mayo <br>
# Autora: Joan Jennier Martínez P. (UC Berkeley)

# %%
from __future__ import with_statement
import os 
import pandas as pd
import numpy as np
import unidecode
import csv
import shutil

# Determining working path
PATH = "/Users/martinezp_jj/Dropbox/__Berkeley/11 Summer 2020/peru-covid19-datalab/"
data_output_path = "datos/procesados/"
data_path = "datos/sin-procesar/"
script_path = "codigo"


# Removing spanish accents data
#Source: https://gist.github.com/Gabriel-Chen/774801e1fc7a28265f57e5c3642b25dc
def remove_accent (feed):
    csv_f = open(feed, encoding='iso-8859-1', mode='r')
    csv_str = csv_f.read()
    csv_str_removed_accent = unidecode.unidecode(csv_str)
    csv_f.close()
    csv_f = open(feed, 'w')
    csv_f.write(csv_str_removed_accent)
    return True

# %% [markdown]
# #### 1-minsa-epp

# %%
## Loading data
fname = os.path.join(PATH, data_path , "1-minsa-epp/ADQUISICIONES-limpio.csv")
df = pd.read_csv(fname, sep=',', header=0,names= ['Fecha', 'RUC','NombreProveedor', 'Producto','Cantidad'])

# Rewrites file without accents
if __name__ == "__main__":
    remove_accent(fname)

# Loading view
pd.set_option('display.max_columns', 999)

# Inpect the df
df.shape   #Rows = 313, Cols = 5
df.dtypes
print("-----------Name of columns-----------", "\n", df.columns)
print("-----------Information of dataset----------")
print(df.info(null_counts=True))

# Correccion de formato de variables
dfn = df.convert_dtypes()
dfn
dfn.dtypes
print("-----------Name of columns-----------", "\n", df.columns)
print("-----------Information of dataset----------")
print(dfn.info(null_counts=True))

# Saving processed data
fname = os.path.join(PATH, data_output_path , "1-minsa-epp.csv")
dfn.to_csv(fname, index=False)
# Out:
# -----------Name of columns-----------
#  Index(['Fecha', 'RUC', 'NombreProveedor', 'Producto', 'Cantidad'], dtype='object')
# -----------Information of dataset----------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 313 entries, 0 to 312
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Fecha            313 non-null    object
#  1   RUC              313 non-null    int64
#  2   NombreProveedor  313 non-null    object
#  3   Producto         313 non-null    object
#  4   Cantidad         313 non-null    int64
# dtypes: int64(2), object(3)
# memory usage: 12.4+ KB
# None
# -----------Name of columns-----------
#  Index(['Fecha', 'RUC', 'NombreProveedor', 'Producto', 'Cantidad'], dtype='object')
# -----------Information of dataset----------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 313 entries, 0 to 312
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Fecha            313 non-null    string
#  1   RUC              313 non-null    Int64
#  2   NombreProveedor  313 non-null    string
#  3   Producto         313 non-null    string
#  4   Cantidad         313 non-null    Int64
# dtypes: Int64(2), string(3)
# memory usage: 13.0 KB
# None

# %% [markdown]
# #### 2-minsa-fallecidos-covid

# %%
## Loading data
fname = os.path.join(PATH, data_path , "2-minsa-fallecidos-covid/FALLECIDOS_CDC-limpio.csv")

# Rewrites file without accents
if __name__ == "__main__":
    remove_accent(fname)

# Load Dataframe
df = pd.read_csv(fname, engine='python', header=0, sep=',',
                 names= ['UUID', 'FechaFallecimiento','Genero', 'FechaNacimiento','Departamento','Provincia','Distrito'])

# Inpect the df
df.shape   #Rows = 3456, Cols = 7
df.dtypes
print("-----------Name of columns-----------", "\n", df.columns)
print("-----------Information of dataset----------")
print(df.info(null_counts=True))


# Genero
df['Genero'].values
df.replace({'Genero': {'MASCULINO': "Hombre", 'FEMENINO' : "Mujer"}}, inplace= True)

# Correccion de formato de variables
dfn = df.convert_dtypes()

# Correccion de fechas
dfn['FechaFallecimiento'] = pd.to_datetime(dfn['FechaFallecimiento'], infer_datetime_format=True)
dfn['FechaNacimiento'] = pd.to_datetime(dfn['FechaNacimiento'], infer_datetime_format=True)

#Creacion variable edad
ahora = pd.Timestamp('now')
dfn['Edad'] = (ahora - dfn['FechaNacimiento']).astype('<m8[Y]')

#Reporte de typos de variable
dfn.dtypes
print("-----------Name of columns-----------", "\n", df.columns)
print("-----------Information of dataset----------")
print(dfn.info(null_counts=True))

# Saving processed data
fname = os.path.join(PATH, data_output_path , "2-minsa-fallecidos-covid.csv")
dfn.to_csv(fname, index=False)
# Out:
# -----------Name of columns-----------
#  Index(['UUID', 'FechaFallecimiento', 'Genero', 'FechaNacimiento',
#        'Departamento', 'Provincia', 'Distrito'],
#       dtype='object')
# -----------Information of dataset----------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3456 entries, 0 to 3455
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   UUID                3456 non-null   object
#  1   FechaFallecimiento  3456 non-null   object
#  2   Genero              3456 non-null   object
#  3   FechaNacimiento     2917 non-null   object
#  4   Departamento        3456 non-null   object
#  5   Provincia           2378 non-null   object
#  6   Distrito            2745 non-null   object
# dtypes: object(7)
# memory usage: 189.1+ KB
# None
# -----------Name of columns-----------
#  Index(['UUID', 'FechaFallecimiento', 'Genero', 'FechaNacimiento',
#        'Departamento', 'Provincia', 'Distrito'],
#       dtype='object')
# -----------Information of dataset----------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3456 entries, 0 to 3455
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   UUID                3456 non-null   string
#  1   FechaFallecimiento  3456 non-null   datetime64[ns]
#  2   Genero              3456 non-null   string
#  3   FechaNacimiento     2917 non-null   datetime64[ns]
#  4   Departamento        3456 non-null   string
#  5   Provincia           2378 non-null   string
#  6   Distrito            2745 non-null   string
#  7   Edad                2917 non-null   float64
# dtypes: datetime64[ns](2), float64(1), string(5)
# memory usage: 216.1 KB
# None

# %% [markdown]
# #### 3-minsa-sinadef

# %%
fname = os.path.join(PATH, data_path , "3-minsa-sinadef/SINADEF_DATOS_ABIERTOS_23052020-limpio.csv")

# Rewrites file without accents
if __name__ == "__main__":
    remove_accent(fname)

df = pd.read_csv(fname, engine= 'python', sep= ';', skiprows= [0,1,2], error_bad_lines=False, usecols= range(1, 19),
                names= ['SeguroTipo', 'Genero', 'Edad', 'EdadUnidad', 'EstadoCivil',
       'NivelEducacion', 'UbigeoDomicilio', 'DomicilioPais',
       'DomicilioDepartamento', 'DomicilioProvincia', 'DomicilioDistrito',
       'DefuncionFecha', 'DefuncionAnio', 'DefuncionMes', 'DefuncionLugar', 'DefuncionInstitucion', 
        'MuerteViolenta',
       'Necropsia'])

# Loading view
pd.set_option('display.max_columns', 999)

# Inpect the df
df.shape   #Rows = 119 959, Cols = 9
df.dtypes
print("-----------Name of columns-----------", "\n", df.columns)
print("-----------Information of dataset----------")
print(df.info(null_counts=True))

# Correccion de valores de variables
# Genero
df.replace({'Genero': {'MASCULINO': "Hombre", 'FEMENINO' : "Mujer"}}, inplace= True)
# df.replace({'Necropsia': {'no se realizo necropsia ': "No", 'si se realizo necropsia' : "Si", 
#                           'sin registro': 'sin registro'}}, inplace= True)

#A minusculas
df['SeguroTipo'] = df['SeguroTipo'].str.lower()
df['EdadUnidad'] = df['EdadUnidad'].str.lower()
df['NivelEducacion'] = df['NivelEducacion'].str.lower()
df['EstadoCivil'] = df['EstadoCivil'].str.lower()
df['DomicilioPais'] = df['DomicilioPais'].str.lower()
df['DomicilioDepartamento'] = df['DomicilioDepartamento'].str.lower()
df['DomicilioProvincia'] = df['DomicilioProvincia'].str.lower()
df['DomicilioDistrito'] = df['DomicilioDistrito'].str.lower()
df['DefuncionLugar'] = df['DefuncionLugar'].str.lower()
df['DefuncionInstitucion'] = df['DefuncionInstitucion'].str.lower()
df['MuerteViolenta'] = df['MuerteViolenta'].str.lower()
df['Necropsia'] = df['Necropsia'].str.lower()

# Correccion de formato de variables
dfn = df.convert_dtypes()
dfn.dtypes
print("-----------Name of columns-----------", "\n", df.columns)
print("-----------Information of dataset----------")
print(dfn.info(null_counts=True))

# Correccion de fechas
dfn['DefuncionFecha'] = pd.to_datetime(dfn['DefuncionFecha'], infer_datetime_format=True)

# # Saving processed data
fname = os.path.join(PATH, data_output_path , "3-minsa-sinadef.csv")
dfn.to_csv(fname, index=False)
# Out:
# -----------Name of columns-----------
#  Index(['SeguroTipo', 'Genero', 'Edad', 'EdadUnidad', 'EstadoCivil',
#        'NivelEducacion', 'UbigeoDomicilio', 'DomicilioPais',
#        'DomicilioDepartamento', 'DomicilioProvincia', 'DomicilioDistrito',
#        'DefuncionFecha', 'DefuncionAnio', 'DefuncionMes', 'DefuncionLugar',
#        'DefuncionInstitucion', 'MuerteViolenta', 'Necropsia'],
#       dtype='object')
# -----------Information of dataset----------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 383207 entries, 0 to 383206
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   SeguroTipo             383207 non-null  object
#  1   Genero                 383207 non-null  object
#  2   Edad                   383207 non-null  object
#  3   EdadUnidad             383207 non-null  object
#  4   EstadoCivil            383207 non-null  object
#  5   NivelEducacion         383207 non-null  object
#  6   UbigeoDomicilio        383207 non-null  object
#  7   DomicilioPais          383207 non-null  object
#  8   DomicilioDepartamento  383207 non-null  object
#  9   DomicilioProvincia     383207 non-null  object
#  10  DomicilioDistrito      383207 non-null  object
#  11  DefuncionFecha         383207 non-null  object
#  12  DefuncionAnio          383207 non-null  int64
#  13  DefuncionMes           383207 non-null  int64
#  14  DefuncionLugar         383207 non-null  object
#  15  DefuncionInstitucion   383207 non-null  object
#  16  MuerteViolenta         383207 non-null  object
#  17  Necropsia              383207 non-null  object
# dtypes: int64(2), object(16)
# memory usage: 52.6+ MB
# None
# -----------Name of columns-----------
#  Index(['SeguroTipo', 'Genero', 'Edad', 'EdadUnidad', 'EstadoCivil',
#        'NivelEducacion', 'UbigeoDomicilio', 'DomicilioPais',
#        'DomicilioDepartamento', 'DomicilioProvincia', 'DomicilioDistrito',
#        'DefuncionFecha', 'DefuncionAnio', 'DefuncionMes', 'DefuncionLugar',
#        'DefuncionInstitucion', 'MuerteViolenta', 'Necropsia'],
#       dtype='object')
# -----------Information of dataset----------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 383207 entries, 0 to 383206
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   SeguroTipo             383207 non-null  string
#  1   Genero                 383207 non-null  string
#  2   Edad                   383207 non-null  string
#  3   EdadUnidad             383207 non-null  string
#  4   EstadoCivil            383207 non-null  string
#  5   NivelEducacion         383207 non-null  string
#  6   UbigeoDomicilio        383207 non-null  string
#  7   DomicilioPais          383207 non-null  string
#  8   DomicilioDepartamento  383207 non-null  string
#  9   DomicilioProvincia     383207 non-null  string
#  10  DomicilioDistrito      383207 non-null  string
#  11  DefuncionFecha         383207 non-null  string
#  12  DefuncionAnio          383207 non-null  Int64
#  13  DefuncionMes           383207 non-null  Int64
#  14  DefuncionLugar         383207 non-null  string
#  15  DefuncionInstitucion   383207 non-null  string
#  16  MuerteViolenta         383207 non-null  string
#  17  Necropsia              383207 non-null  string
# dtypes: Int64(2), string(16)
# memory usage: 53.4 MB
# None

# %% [markdown]
# #### 4-minsa-contagiados-covid

# %%
## Loading data
fname = os.path.join(PATH, data_path , "4-minsa-contagiados-covid/DATOSABIERTOS_SISCOVID-limpio.csv")

# Rewrites file without accents
if __name__ == "__main__":
    remove_accent(fname)

df = pd.read_csv(fname, engine='python', sep=',', header=0, 
                 names= ['UUID', 'Departamento','Provincia', 'Distrito','MetodoDiagnostico-abv','Edad','Genero', 'FechaDiagnostico'])

# Loading view
pd.set_option('display.max_columns', 999)

# Inpect the df
df.shape   #Rows = 119 959, Cols = 9
df.dtypes
print("-----------Name of columns-----------", "\n", df.columns)
print("-----------Information of dataset----------")
print(df.info(null_counts=True))

# # Correccion de valores de variables

# Genero
df['Genero'].values
df.replace({'Genero': {'MASCULINO': "Hombre", 'FEMENINO' : "Mujer"}}, inplace= True)

#Metodos de diagnostico
df['MetodoDiagnostico']= df['MetodoDiagnostico-abv']
df.replace({'MetodoDiagnostico': {'PCR': "Prueba reacción en cadena de poliomerasa (PCR)", 
                                  'PR' : "Prueba rápida"}}, inplace= True)

# Correccion de formato de variables
dfn = df.convert_dtypes()
dfn
dfn.dtypes
print("-----------Name of columns-----------", "\n", df.columns)
print("-----------Information of dataset----------")
print(dfn.info(null_counts=True))

# Correccion de fechas
dfn['FechaDiagnostico'] = pd.to_datetime(dfn['FechaDiagnostico'], infer_datetime_format=True)

# Saving processed data
fname = os.path.join(PATH, data_output_path , "4-minsa-contagiados-covid.csv")
dfn.to_csv(fname, index=False)
# Out:
# -----------Name of columns-----------
#  Index(['UUID', 'Departamento', 'Provincia', 'Distrito',
#        'MetodoDiagnostico-abv', 'Edad', 'Genero', 'FechaDiagnostico'],
#       dtype='object')
# -----------Information of dataset----------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119959 entries, 0 to 119958
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   UUID                   119959 non-null  object
#  1   Departamento           119959 non-null  object
#  2   Provincia              119959 non-null  object
#  3   Distrito               119959 non-null  object
#  4   MetodoDiagnostico-abv  119959 non-null  object
#  5   Edad                   117420 non-null  float64
#  6   Genero                 116576 non-null  object
#  7   FechaDiagnostico       115508 non-null  object
# dtypes: float64(1), object(7)
# memory usage: 7.3+ MB
# None
# -----------Name of columns-----------
#  Index(['UUID', 'Departamento', 'Provincia', 'Distrito',
#        'MetodoDiagnostico-abv', 'Edad', 'Genero', 'FechaDiagnostico',
#        'MetodoDiagnostico'],
#       dtype='object')
# -----------Information of dataset----------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119959 entries, 0 to 119958
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   UUID                   119959 non-null  string
#  1   Departamento           119959 non-null  string
#  2   Provincia              119959 non-null  string
#  3   Distrito               119959 non-null  string
#  4   MetodoDiagnostico-abv  119959 non-null  string
#  5   Edad                   117420 non-null  Int64
#  6   Genero                 116576 non-null  string
#  7   FechaDiagnostico       115508 non-null  string
#  8   MetodoDiagnostico      119959 non-null  string
# dtypes: Int64(1), string(8)
# memory usage: 8.4 MB
# None

# %% [markdown]
# #### 5-pcm-mef-donaciones

# %%
## Loading data (copy with accents)
fname = os.path.join(PATH, data_path , "5-pcm-mef-donaciones/pcm_donaciones-limpio.csv")

# Rewrites file without accents
if __name__ == "__main__":
    remove_accent(fname)

df = pd.read_csv(fname, engine='python', sep=',', header=0, 
                 names=['AnioEje', 'Region', 'TipoGobiernoAbv', 'TipoGobierno', 'SectorCod', 'Sector', 'PliegoCod', 'Pliego', 'SecuenciaEjecutoraCod', 'EjecutoraCod', 'Ejecutora', 'AlmacenCod', 'SecuenciaAlmacenCod', 'Almacen', 'TipoTransaccionCod', 'TipoTransaccion', 'MovimientoID', 'OrdenCompraID', 'ProveedorCodigo', 'Proveedor', 'ObservacionDonacion', 'MovimientoFecha','MovimientoMesCod', 'MovimientoMes', 'TipoUsoCodigo', 'GuiaRemisionCodigo', 'FacturaNumero', 'EstadoKardex','FechaRegistro', 'ConformidadIngresoDocumento', 'ConformidadIngresoFecha', 'IngresoGlosa', 'BienTipoCod', 'BienGrupoCod', 'BienGrupo', 'BienClaseCod', 'BienClase', 'BienFamiliaCod', 'BienFamilia', 'BienItemCod', 'BienItem', 'BienUnidaMedidaCod','BienUnidadMedida', 'BienMarcaCod','BienMarca','BienCantidad', 'BienPrecioUnitario', 'BienValorTotal'])

# Inpect the df
df.shape   #Rows = 1 090, Cols = 48
df.dtypes
print("-----------Name of columns-----------", "\n", df.columns)
print("-----------Information of dataset----------")
print(df.info(null_counts=True))

# # Correccion de valores de variables 

# Correccion de formato de variables
dfn = df.convert_dtypes()
dfn
dfn.dtypes
print("-----------Name of columns-----------", "\n", df.columns)
print("-----------Information of dataset----------")
print(dfn.info(null_counts=True))

# # Correccion de fechas
dfn['MovimientoFecha'] = pd.to_datetime(dfn['MovimientoFecha'], infer_datetime_format=True)
dfn['FechaRegistro'] = pd.to_datetime(dfn['FechaRegistro'], infer_datetime_format=True)
dfn['ConformidadIngresoFecha'] = pd.to_datetime(dfn['ConformidadIngresoFecha'], infer_datetime_format=True)

# Saving processed data
fname = os.path.join(PATH, data_output_path , "5-pcm-mef-donaciones.csv")
dfn.to_csv(fname, index=False)
# Out:
# -----------Name of columns-----------
#  Index(['AnioEje', 'Region', 'TipoGobiernoAbv', 'TipoGobierno', 'SectorCod',
#        'Sector', 'PliegoCod', 'Pliego', 'SecuenciaEjecutoraCod',
#        'EjecutoraCod', 'Ejecutora', 'AlmacenCod', 'SecuenciaAlmacenCod',
#        'Almacen', 'TipoTransaccionCod', 'TipoTransaccion', 'MovimientoID',
#        'OrdenCompraID', 'ProveedorCodigo', 'Proveedor', 'ObservacionDonacion',
#        'MovimientoFecha', 'MovimientoMesCod', 'MovimientoMes', 'TipoUsoCodigo',
#        'GuiaRemisionCodigo', 'FacturaNumero', 'EstadoKardex', 'FechaRegistro',
#        'ConformidadIngresoDocumento', 'ConformidadIngresoFecha',
#        'IngresoGlosa', 'BienTipoCod', 'BienGrupoCod', 'BienGrupo',
#        'BienClaseCod', 'BienClase', 'BienFamiliaCod', 'BienFamilia',
#        'BienItemCod', 'BienItem', 'BienUnidaMedidaCod', 'BienUnidadMedida',
#        'BienMarcaCod', 'BienMarca', 'BienCantidad', 'BienPrecioUnitario',
#        'BienValorTotal'],
#       dtype='object')
# -----------Information of dataset----------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1090 entries, 0 to 1089
# Data columns (total 48 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   AnioEje                      1090 non-null   int64
#  1   Region                       1090 non-null   object
#  2   TipoGobiernoAbv              1090 non-null   object
#  3   TipoGobierno                 1090 non-null   object
#  4   SectorCod                    1090 non-null   int64
#  5   Sector                       1090 non-null   object
#  6   PliegoCod                    1090 non-null   int64
#  7   Pliego                       1090 non-null   object
#  8   SecuenciaEjecutoraCod        1090 non-null   int64
#  9   EjecutoraCod                 1090 non-null   int64
#  10  Ejecutora                    1090 non-null   object
#  11  AlmacenCod                   1090 non-null   int64
#  12  SecuenciaAlmacenCod          1090 non-null   int64
#  13  Almacen                      1090 non-null   object
#  14  TipoTransaccionCod           1090 non-null   int64
#  15  TipoTransaccion              1090 non-null   object
#  16  MovimientoID                 1090 non-null   int64
#  17  OrdenCompraID                1090 non-null   int64
#  18  ProveedorCodigo              1090 non-null   int64
#  19  Proveedor                    1090 non-null   object
#  20  ObservacionDonacion          993 non-null    object
#  21  MovimientoFecha              1090 non-null   object
#  22  MovimientoMesCod             1090 non-null   int64
#  23  MovimientoMes                1090 non-null   object
#  24  TipoUsoCodigo                1090 non-null   object
#  25  GuiaRemisionCodigo           1090 non-null   object
#  26  FacturaNumero                1047 non-null   object
#  27  EstadoKardex                 1090 non-null   object
#  28  FechaRegistro                1090 non-null   object
#  29  ConformidadIngresoDocumento  986 non-null    object
#  30  ConformidadIngresoFecha      1079 non-null   object
#  31  IngresoGlosa                 991 non-null    object
#  32  BienTipoCod                  1090 non-null   object
#  33  BienGrupoCod                 1090 non-null   int64
#  34  BienGrupo                    1090 non-null   object
#  35  BienClaseCod                 1090 non-null   int64
#  36  BienClase                    1090 non-null   object
#  37  BienFamiliaCod               1090 non-null   int64
#  38  BienFamilia                  1090 non-null   object
#  39  BienItemCod                  1090 non-null   int64
#  40  BienItem                     1090 non-null   object
#  41  BienUnidaMedidaCod           1090 non-null   int64
#  42  BienUnidadMedida             1090 non-null   object
#  43  BienMarcaCod                 1090 non-null   int64
#  44  BienMarca                    1090 non-null   object
#  45  BienCantidad                 1090 non-null   float64
#  46  BienPrecioUnitario           1090 non-null   float64
#  47  BienValorTotal               1090 non-null   float64
# dtypes: float64(3), int64(18), object(27)
# memory usage: 408.9+ KB
# None
# -----------Name of columns-----------
#  Index(['AnioEje', 'Region', 'TipoGobiernoAbv', 'TipoGobierno', 'SectorCod',
#        'Sector', 'PliegoCod', 'Pliego', 'SecuenciaEjecutoraCod',
#        'EjecutoraCod', 'Ejecutora', 'AlmacenCod', 'SecuenciaAlmacenCod',
#        'Almacen', 'TipoTransaccionCod', 'TipoTransaccion', 'MovimientoID',
#        'OrdenCompraID', 'ProveedorCodigo', 'Proveedor', 'ObservacionDonacion',
#        'MovimientoFecha', 'MovimientoMesCod', 'MovimientoMes', 'TipoUsoCodigo',
#        'GuiaRemisionCodigo', 'FacturaNumero', 'EstadoKardex', 'FechaRegistro',
#        'ConformidadIngresoDocumento', 'ConformidadIngresoFecha',
#        'IngresoGlosa', 'BienTipoCod', 'BienGrupoCod', 'BienGrupo',
#        'BienClaseCod', 'BienClase', 'BienFamiliaCod', 'BienFamilia',
#        'BienItemCod', 'BienItem', 'BienUnidaMedidaCod', 'BienUnidadMedida',
#        'BienMarcaCod', 'BienMarca', 'BienCantidad', 'BienPrecioUnitario',
#        'BienValorTotal'],
#       dtype='object')
# -----------Information of dataset----------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1090 entries, 0 to 1089
# Data columns (total 48 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   AnioEje                      1090 non-null   Int64
#  1   Region                       1090 non-null   string
#  2   TipoGobiernoAbv              1090 non-null   string
#  3   TipoGobierno                 1090 non-null   string
#  4   SectorCod                    1090 non-null   Int64
#  5   Sector                       1090 non-null   string
#  6   PliegoCod                    1090 non-null   Int64
#  7   Pliego                       1090 non-null   string
#  8   SecuenciaEjecutoraCod        1090 non-null   Int64
#  9   EjecutoraCod                 1090 non-null   Int64
#  10  Ejecutora                    1090 non-null   string
#  11  AlmacenCod                   1090 non-null   Int64
#  12  SecuenciaAlmacenCod          1090 non-null   Int64
#  13  Almacen                      1090 non-null   string
#  14  TipoTransaccionCod           1090 non-null   Int64
#  15  TipoTransaccion              1090 non-null   string
#  16  MovimientoID                 1090 non-null   Int64
#  17  OrdenCompraID                1090 non-null   Int64
#  18  ProveedorCodigo              1090 non-null   Int64
#  19  Proveedor                    1090 non-null   string
#  20  ObservacionDonacion          993 non-null    string
#  21  MovimientoFecha              1090 non-null   string
#  22  MovimientoMesCod             1090 non-null   Int64
#  23  MovimientoMes                1090 non-null   string
#  24  TipoUsoCodigo                1090 non-null   string
#  25  GuiaRemisionCodigo           1090 non-null   string
#  26  FacturaNumero                1047 non-null   string
#  27  EstadoKardex                 1090 non-null   string
#  28  FechaRegistro                1090 non-null   string
#  29  ConformidadIngresoDocumento  986 non-null    string
#  30  ConformidadIngresoFecha      1079 non-null   string
#  31  IngresoGlosa                 991 non-null    string
#  32  BienTipoCod                  1090 non-null   string
#  33  BienGrupoCod                 1090 non-null   Int64
#  34  BienGrupo                    1090 non-null   string
#  35  BienClaseCod                 1090 non-null   Int64
#  36  BienClase                    1090 non-null   string
#  37  BienFamiliaCod               1090 non-null   Int64
#  38  BienFamilia                  1090 non-null   string
#  39  BienItemCod                  1090 non-null   Int64
#  40  BienItem                     1090 non-null   string
#  41  BienUnidaMedidaCod           1090 non-null   Int64
#  42  BienUnidadMedida             1090 non-null   string
#  43  BienMarcaCod                 1090 non-null   Int64
#  44  BienMarca                    1090 non-null   string
#  45  BienCantidad                 1090 non-null   float64
#  46  BienPrecioUnitario           1090 non-null   float64
#  47  BienValorTotal               1090 non-null   float64
# dtypes: Int64(18), float64(3), string(27)
# memory usage: 428.0 KB
# None

# %% [markdown]
# #### 6-pcm_ejecucion

# %%
## Loading data
fname = os.path.join(PATH, data_path , "6-pcm_ejecucion/pcm_covid-limpio.csv")

## Removing accents
if __name__ == "__main__":
    remove_accent(fname)

df = pd.read_csv(fname, engine= 'python', sep= ',')

# Inpect the df
df.shape   #Rows = 1 090, Cols = 48
df.dtypes
print("-----------Name of columns-----------", "\n", df.columns)
print("-----------Information of dataset----------")
print(df.info(null_counts=True))

# # Correccion de valores de variables 

# Correccion de formato de variables
dfn = df.convert_dtypes()
dfn
dfn.dtypes
print("-----------Name of columns-----------", "\n", df.columns)
print("-----------Information of dataset----------")
print(dfn.info(null_counts=True))

# Saving processed data
fname = os.path.join(PATH, data_output_path , "6-pcm_ejecucion.csv")
dfn.to_csv(fname, index=False)
# Out:
# -----------Name of columns-----------
#  Index(['ANO_EJE', 'MES_EJE', 'TIPO_GOBIERNO', 'TIPO_GOBIERNO_NOMBRE', 'SECTOR',
#        'SECTOR_NOMBRE', 'PLIEGO', 'PLIEGO_NOMBRE', 'SEC_EJEC', 'EJECUTORA',
#        'EJECUTORA_NOMBRE', 'DEPARTAMENTO_EJECUTORA',
#        'DEPARTAMENTO_EJECUTORA_NOMBRE', 'PROVINCIA_EJECUTORA',
#        'PROVINCIA_EJECUTORA_NOMBRE', 'DISTRITO_EJECUTORA',
#        'DISTRITO_EJECUTORA_NOMBRE', 'SEC_FUNC', 'PROGRAMA_PPTO',
#        'PROGRAMA_PPTO_NOMBRE', 'TIPO_ACT_PROY', 'PRODUCTO_PROYECTO',
#        'PRODUCTO_PROYECTO_NOMBRE', 'ACTIVIDAD_ACCION_OBRA',
#        'ACTIVIDAD_ACCION_OBRA_NOMBRE', 'FUNCION', 'FUNCION_NOMBRE',
#        'DIVISION_FUNCIONAL', 'DIVISION_FUNCIONAL_NOMBRE', 'GRUPO_FUNCIONAL',
#        'GRUPO_FUNCIONAL_NOMBRE', 'META', 'FINALIDAD', 'META_NOMBRE',
#        'DEPARTAMENTO_META', 'DEPARTAMENTO_META_NOMBRE', 'RUBRO',
#        'RUBRO_NOMBRE', 'FUENTE_FINANC', 'FUENTE_FINANC_NOMBRE', 'TIPO_RECURSO',
#        'TIPO_RECURSO_NOMBRE', 'CATEG_GASTO', 'CATEG_GASTO_NOMBRE',
#        'TIPO_TRANSACCION', 'GENERICA', 'GENERICA_NOMBRE', 'SUBGENERICA',
#        'SUBGENERICA_NOMBRE', 'SUBGENERICA_DET', 'SUBGENERICA_DET_NOMBRE',
#        'ESPECIFICA', 'ESPECIFICA_NOMBRE', 'ESPECIFICA_DET',
#        'ESPECIFICA_DET_NOMBRE', 'MONTO_PIA', 'MONTO_PIM', 'MONTO_CERTIFICADO',
#        'MONTO_COMPROMETIDO_ANUAL', 'MONTO_COMPROMETIDO', 'MONTO_DEVENGADO',
#        'MONTO_GIRADO'],
#       dtype='object')
# -----------Information of dataset----------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45873 entries, 0 to 45872
# Data columns (total 62 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ANO_EJE                        45873 non-null  int64
#  1   MES_EJE                        45873 non-null  int64
#  2   TIPO_GOBIERNO                  45873 non-null  object
#  3   TIPO_GOBIERNO_NOMBRE           45873 non-null  object
#  4   SECTOR                         45873 non-null  int64
#  5   SECTOR_NOMBRE                  45873 non-null  object
#  6   PLIEGO                         45873 non-null  int64
#  7   PLIEGO_NOMBRE                  45873 non-null  object
#  8   SEC_EJEC                       45873 non-null  int64
#  9   EJECUTORA                      45873 non-null  int64
#  10  EJECUTORA_NOMBRE               45873 non-null  object
#  11  DEPARTAMENTO_EJECUTORA         45873 non-null  int64
#  12  DEPARTAMENTO_EJECUTORA_NOMBRE  45873 non-null  object
#  13  PROVINCIA_EJECUTORA            45873 non-null  int64
#  14  PROVINCIA_EJECUTORA_NOMBRE     45873 non-null  object
#  15  DISTRITO_EJECUTORA             45873 non-null  int64
#  16  DISTRITO_EJECUTORA_NOMBRE      45873 non-null  object
#  17  SEC_FUNC                       45873 non-null  int64
#  18  PROGRAMA_PPTO                  45873 non-null  int64
#  19  PROGRAMA_PPTO_NOMBRE           45873 non-null  object
#  20  TIPO_ACT_PROY                  45873 non-null  object
#  21  PRODUCTO_PROYECTO              45873 non-null  int64
#  22  PRODUCTO_PROYECTO_NOMBRE       45873 non-null  object
#  23  ACTIVIDAD_ACCION_OBRA          45873 non-null  int64
#  24  ACTIVIDAD_ACCION_OBRA_NOMBRE   45873 non-null  object
#  25  FUNCION                        45873 non-null  int64
#  26  FUNCION_NOMBRE                 45873 non-null  object
#  27  DIVISION_FUNCIONAL             45873 non-null  int64
#  28  DIVISION_FUNCIONAL_NOMBRE      45873 non-null  object
#  29  GRUPO_FUNCIONAL                45873 non-null  int64
#  30  GRUPO_FUNCIONAL_NOMBRE         45873 non-null  object
#  31  META                           45873 non-null  int64
#  32  FINALIDAD                      45873 non-null  int64
#  33  META_NOMBRE                    45873 non-null  object
#  34  DEPARTAMENTO_META              45873 non-null  int64
#  35  DEPARTAMENTO_META_NOMBRE       45873 non-null  object
#  36  RUBRO                          45873 non-null  int64
#  37  RUBRO_NOMBRE                   45873 non-null  object
#  38  FUENTE_FINANC                  45873 non-null  int64
#  39  FUENTE_FINANC_NOMBRE           45873 non-null  object
#  40  TIPO_RECURSO                   45873 non-null  object
#  41  TIPO_RECURSO_NOMBRE            45873 non-null  object
#  42  CATEG_GASTO                    45873 non-null  int64
#  43  CATEG_GASTO_NOMBRE             45873 non-null  object
#  44  TIPO_TRANSACCION               45873 non-null  int64
#  45  GENERICA                       45873 non-null  int64
#  46  GENERICA_NOMBRE                45873 non-null  object
#  47  SUBGENERICA                    45873 non-null  int64
#  48  SUBGENERICA_NOMBRE             45873 non-null  object
#  49  SUBGENERICA_DET                45873 non-null  int64
#  50  SUBGENERICA_DET_NOMBRE         45873 non-null  object
#  51  ESPECIFICA                     45873 non-null  int64
#  52  ESPECIFICA_NOMBRE              45873 non-null  object
#  53  ESPECIFICA_DET                 45873 non-null  int64
#  54  ESPECIFICA_DET_NOMBRE          45873 non-null  object
#  55  MONTO_PIA                      45873 non-null  int64
#  56  MONTO_PIM                      45873 non-null  int64
#  57  MONTO_CERTIFICADO              45873 non-null  int64
#  58  MONTO_COMPROMETIDO_ANUAL       45873 non-null  int64
#  59  MONTO_COMPROMETIDO             45873 non-null  int64
#  60  MONTO_DEVENGADO                45873 non-null  int64
#  61  MONTO_GIRADO                   45873 non-null  int64
# dtypes: int64(35), object(27)
# memory usage: 21.7+ MB
# None
# -----------Name of columns-----------
#  Index(['ANO_EJE', 'MES_EJE', 'TIPO_GOBIERNO', 'TIPO_GOBIERNO_NOMBRE', 'SECTOR',
#        'SECTOR_NOMBRE', 'PLIEGO', 'PLIEGO_NOMBRE', 'SEC_EJEC', 'EJECUTORA',
#        'EJECUTORA_NOMBRE', 'DEPARTAMENTO_EJECUTORA',
#        'DEPARTAMENTO_EJECUTORA_NOMBRE', 'PROVINCIA_EJECUTORA',
#        'PROVINCIA_EJECUTORA_NOMBRE', 'DISTRITO_EJECUTORA',
#        'DISTRITO_EJECUTORA_NOMBRE', 'SEC_FUNC', 'PROGRAMA_PPTO',
#        'PROGRAMA_PPTO_NOMBRE', 'TIPO_ACT_PROY', 'PRODUCTO_PROYECTO',
#        'PRODUCTO_PROYECTO_NOMBRE', 'ACTIVIDAD_ACCION_OBRA',
#        'ACTIVIDAD_ACCION_OBRA_NOMBRE', 'FUNCION', 'FUNCION_NOMBRE',
#        'DIVISION_FUNCIONAL', 'DIVISION_FUNCIONAL_NOMBRE', 'GRUPO_FUNCIONAL',
#        'GRUPO_FUNCIONAL_NOMBRE', 'META', 'FINALIDAD', 'META_NOMBRE',
#        'DEPARTAMENTO_META', 'DEPARTAMENTO_META_NOMBRE', 'RUBRO',
#        'RUBRO_NOMBRE', 'FUENTE_FINANC', 'FUENTE_FINANC_NOMBRE', 'TIPO_RECURSO',
#        'TIPO_RECURSO_NOMBRE', 'CATEG_GASTO', 'CATEG_GASTO_NOMBRE',
#        'TIPO_TRANSACCION', 'GENERICA', 'GENERICA_NOMBRE', 'SUBGENERICA',
#        'SUBGENERICA_NOMBRE', 'SUBGENERICA_DET', 'SUBGENERICA_DET_NOMBRE',
#        'ESPECIFICA', 'ESPECIFICA_NOMBRE', 'ESPECIFICA_DET',
#        'ESPECIFICA_DET_NOMBRE', 'MONTO_PIA', 'MONTO_PIM', 'MONTO_CERTIFICADO',
#        'MONTO_COMPROMETIDO_ANUAL', 'MONTO_COMPROMETIDO', 'MONTO_DEVENGADO',
#        'MONTO_GIRADO'],
#       dtype='object')
# -----------Information of dataset----------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45873 entries, 0 to 45872
# Data columns (total 62 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ANO_EJE                        45873 non-null  Int64
#  1   MES_EJE                        45873 non-null  Int64
#  2   TIPO_GOBIERNO                  45873 non-null  string
#  3   TIPO_GOBIERNO_NOMBRE           45873 non-null  string
#  4   SECTOR                         45873 non-null  Int64
#  5   SECTOR_NOMBRE                  45873 non-null  string
#  6   PLIEGO                         45873 non-null  Int64
#  7   PLIEGO_NOMBRE                  45873 non-null  string
#  8   SEC_EJEC                       45873 non-null  Int64
#  9   EJECUTORA                      45873 non-null  Int64
#  10  EJECUTORA_NOMBRE               45873 non-null  string
#  11  DEPARTAMENTO_EJECUTORA         45873 non-null  Int64
#  12  DEPARTAMENTO_EJECUTORA_NOMBRE  45873 non-null  string
#  13  PROVINCIA_EJECUTORA            45873 non-null  Int64
#  14  PROVINCIA_EJECUTORA_NOMBRE     45873 non-null  string
#  15  DISTRITO_EJECUTORA             45873 non-null  Int64
#  16  DISTRITO_EJECUTORA_NOMBRE      45873 non-null  string
#  17  SEC_FUNC                       45873 non-null  Int64
#  18  PROGRAMA_PPTO                  45873 non-null  Int64
#  19  PROGRAMA_PPTO_NOMBRE           45873 non-null  string
#  20  TIPO_ACT_PROY                  45873 non-null  string
#  21  PRODUCTO_PROYECTO              45873 non-null  Int64
#  22  PRODUCTO_PROYECTO_NOMBRE       45873 non-null  string
#  23  ACTIVIDAD_ACCION_OBRA          45873 non-null  Int64
#  24  ACTIVIDAD_ACCION_OBRA_NOMBRE   45873 non-null  string
#  25  FUNCION                        45873 non-null  Int64
#  26  FUNCION_NOMBRE                 45873 non-null  string
#  27  DIVISION_FUNCIONAL             45873 non-null  Int64
#  28  DIVISION_FUNCIONAL_NOMBRE      45873 non-null  string
#  29  GRUPO_FUNCIONAL                45873 non-null  Int64
#  30  GRUPO_FUNCIONAL_NOMBRE         45873 non-null  string
#  31  META                           45873 non-null  Int64
#  32  FINALIDAD                      45873 non-null  Int64
#  33  META_NOMBRE                    45873 non-null  string
#  34  DEPARTAMENTO_META              45873 non-null  Int64
#  35  DEPARTAMENTO_META_NOMBRE       45873 non-null  string
#  36  RUBRO                          45873 non-null  Int64
#  37  RUBRO_NOMBRE                   45873 non-null  string
#  38  FUENTE_FINANC                  45873 non-null  Int64
#  39  FUENTE_FINANC_NOMBRE           45873 non-null  string
#  40  TIPO_RECURSO                   45873 non-null  string
#  41  TIPO_RECURSO_NOMBRE            45873 non-null  string
#  42  CATEG_GASTO                    45873 non-null  Int64
#  43  CATEG_GASTO_NOMBRE             45873 non-null  string
#  44  TIPO_TRANSACCION               45873 non-null  Int64
#  45  GENERICA                       45873 non-null  Int64
#  46  GENERICA_NOMBRE                45873 non-null  string
#  47  SUBGENERICA                    45873 non-null  Int64
#  48  SUBGENERICA_NOMBRE             45873 non-null  string
#  49  SUBGENERICA_DET                45873 non-null  Int64
#  50  SUBGENERICA_DET_NOMBRE         45873 non-null  string
#  51  ESPECIFICA                     45873 non-null  Int64
#  52  ESPECIFICA_NOMBRE              45873 non-null  string
#  53  ESPECIFICA_DET                 45873 non-null  Int64
#  54  ESPECIFICA_DET_NOMBRE          45873 non-null  string
#  55  MONTO_PIA                      45873 non-null  Int64
#  56  MONTO_PIM                      45873 non-null  Int64
#  57  MONTO_CERTIFICADO              45873 non-null  Int64
#  58  MONTO_COMPROMETIDO_ANUAL       45873 non-null  Int64
#  59  MONTO_COMPROMETIDO             45873 non-null  Int64
#  60  MONTO_DEVENGADO                45873 non-null  Int64
#  61  MONTO_GIRADO                   45873 non-null  Int64
# dtypes: Int64(35), string(27)
# memory usage: 23.2 MB
# None

# %% [markdown]
# #### 7-osce-contrataciones

# %%
fname = os.path.join(PATH, data_path , "7-osce-contrataciones/CONOSCE_CONTRATACIONDIRECTA-limpio.csv")

## Removing accents
if __name__ == "__main__":
    remove_accent(fname)

df = pd.read_csv(fname, engine= 'python', sep= ',')

# Inpect the df
df.shape   #Rows = 1 048 575, Cols = 10
df.dtypes
print("-----------Name of columns-----------", "\n", df.columns)
print("-----------Information of dataset----------")
print(df.info(null_counts=True))

# Correccion de formato de variables
dfn = df.convert_dtypes()
dfn
dfn.dtypes
print("-----------Name of columns-----------", "\n", df.columns)
print("-----------Information of dataset----------")
print(dfn.info(null_counts=True))

# Saving processed data
fname = os.path.join(PATH, data_output_path , "7-osce-contrataciones.csv")
dfn.to_csv(fname, index=False)
# Out:
# -----------Name of columns-----------
#  Index(['CODIGOENTIDAD', 'RUC_ENTIDAD', 'ENTIDAD', 'ENTIDAD_DEPARTAMENTO',
#        'ENTIDAD_PROVINCIA', 'ENTIDAD_DISTRITO', 'FECHACONVOCATORIA',
#        'OBJETOCONTRACTUAL', 'PROCESO', 'CODIGOCONVOCATORIA',
#        'DESCRIPCION_PROCESO', 'NUMERO_ITEM', 'ITEMCONVOCA_DESCRIPCION',
#        'ITEMCONVOCA_UNIDADMEDIDA', 'SECTOR', 'TIPOENTIDADOEE', 'TIPOPROCESO',
#        'ITEM_DEPARTAMENTO', 'ITEM_PROVINCIA', 'ITEM_DISTRITO',
#        'ESTADOITEMCONVOCA', 'ULTIMO', 'MONEDA', 'CAUSAL_EXOR_CONT_DIRECTA',
#        'MONTOREFERENCIAL', 'MONTOREFERENCIALSOLES', 'MONTOADJUDICADO',
#        'MONTOADJUDICADOSOLES', 'TIPOPROVEEDOR', 'RUCPROVEEDOR', 'PROVEEDOR',
#        'RUCDETALLEPROVEEDOR', 'DETALLEPROVEEDOR', 'URLFICHAPROCESO', 'RUBROS'],
#       dtype='object')
# -----------Information of dataset----------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2676 entries, 0 to 2675
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CODIGOENTIDAD             2676 non-null   int64
#  1   RUC_ENTIDAD               2676 non-null   int64
#  2   ENTIDAD                   2676 non-null   object
#  3   ENTIDAD_DEPARTAMENTO      2676 non-null   object
#  4   ENTIDAD_PROVINCIA         2676 non-null   object
#  5   ENTIDAD_DISTRITO          2676 non-null   object
#  6   FECHACONVOCATORIA         2676 non-null   object
#  7   OBJETOCONTRACTUAL         2676 non-null   object
#  8   PROCESO                   2676 non-null   object
#  9   CODIGOCONVOCATORIA        2676 non-null   int64
#  10  DESCRIPCION_PROCESO       2676 non-null   object
#  11  NUMERO_ITEM               2676 non-null   int64
#  12  ITEMCONVOCA_DESCRIPCION   2676 non-null   object
#  13  ITEMCONVOCA_UNIDADMEDIDA  2676 non-null   object
#  14  SECTOR                    2676 non-null   object
#  15  TIPOENTIDADOEE            2676 non-null   object
#  16  TIPOPROCESO               2676 non-null   object
#  17  ITEM_DEPARTAMENTO         2676 non-null   object
#  18  ITEM_PROVINCIA            2676 non-null   object
#  19  ITEM_DISTRITO             2676 non-null   object
#  20  ESTADOITEMCONVOCA         2676 non-null   object
#  21  ULTIMO                    2676 non-null   object
#  22  MONEDA                    2676 non-null   object
#  23  CAUSAL_EXOR_CONT_DIRECTA  2676 non-null   object
#  24  MONTOREFERENCIAL          2676 non-null   float64
#  25  MONTOREFERENCIALSOLES     2674 non-null   float64
#  26  MONTOADJUDICADO           2676 non-null   float64
#  27  MONTOADJUDICADOSOLES      2674 non-null   float64
#  28  TIPOPROVEEDOR             2676 non-null   object
#  29  RUCPROVEEDOR              2676 non-null   int64
#  30  PROVEEDOR                 2674 non-null   object
#  31  RUCDETALLEPROVEEDOR       25 non-null     float64
#  32  DETALLEPROVEEDOR          25 non-null     object
#  33  URLFICHAPROCESO           2676 non-null   object
#  34  RUBROS                    2676 non-null   object
# dtypes: float64(5), int64(5), object(25)
# memory usage: 731.8+ KB
# None
# -----------Name of columns-----------
#  Index(['CODIGOENTIDAD', 'RUC_ENTIDAD', 'ENTIDAD', 'ENTIDAD_DEPARTAMENTO',
#        'ENTIDAD_PROVINCIA', 'ENTIDAD_DISTRITO', 'FECHACONVOCATORIA',
#        'OBJETOCONTRACTUAL', 'PROCESO', 'CODIGOCONVOCATORIA',
#        'DESCRIPCION_PROCESO', 'NUMERO_ITEM', 'ITEMCONVOCA_DESCRIPCION',
#        'ITEMCONVOCA_UNIDADMEDIDA', 'SECTOR', 'TIPOENTIDADOEE', 'TIPOPROCESO',
#        'ITEM_DEPARTAMENTO', 'ITEM_PROVINCIA', 'ITEM_DISTRITO',
#        'ESTADOITEMCONVOCA', 'ULTIMO', 'MONEDA', 'CAUSAL_EXOR_CONT_DIRECTA',
#        'MONTOREFERENCIAL', 'MONTOREFERENCIALSOLES', 'MONTOADJUDICADO',
#        'MONTOADJUDICADOSOLES', 'TIPOPROVEEDOR', 'RUCPROVEEDOR', 'PROVEEDOR',
#        'RUCDETALLEPROVEEDOR', 'DETALLEPROVEEDOR', 'URLFICHAPROCESO', 'RUBROS'],
#       dtype='object')
# -----------Information of dataset----------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2676 entries, 0 to 2675
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CODIGOENTIDAD             2676 non-null   Int64
#  1   RUC_ENTIDAD               2676 non-null   Int64
#  2   ENTIDAD                   2676 non-null   string
#  3   ENTIDAD_DEPARTAMENTO      2676 non-null   string
#  4   ENTIDAD_PROVINCIA         2676 non-null   string
#  5   ENTIDAD_DISTRITO          2676 non-null   string
#  6   FECHACONVOCATORIA         2676 non-null   string
#  7   OBJETOCONTRACTUAL         2676 non-null   string
#  8   PROCESO                   2676 non-null   string
#  9   CODIGOCONVOCATORIA        2676 non-null   Int64
#  10  DESCRIPCION_PROCESO       2676 non-null   string
#  11  NUMERO_ITEM               2676 non-null   Int64
#  12  ITEMCONVOCA_DESCRIPCION   2676 non-null   string
#  13  ITEMCONVOCA_UNIDADMEDIDA  2676 non-null   string
#  14  SECTOR                    2676 non-null   string
#  15  TIPOENTIDADOEE            2676 non-null   string
#  16  TIPOPROCESO               2676 non-null   string
#  17  ITEM_DEPARTAMENTO         2676 non-null   string
#  18  ITEM_PROVINCIA            2676 non-null   string
#  19  ITEM_DISTRITO             2676 non-null   string
#  20  ESTADOITEMCONVOCA         2676 non-null   string
#  21  ULTIMO                    2676 non-null   string
#  22  MONEDA                    2676 non-null   string
#  23  CAUSAL_EXOR_CONT_DIRECTA  2676 non-null   string
#  24  MONTOREFERENCIAL          2676 non-null   float64
#  25  MONTOREFERENCIALSOLES     2674 non-null   float64
#  26  MONTOADJUDICADO           2676 non-null   float64
#  27  MONTOADJUDICADOSOLES      2674 non-null   float64
#  28  TIPOPROVEEDOR             2676 non-null   string
#  29  RUCPROVEEDOR              2676 non-null   Int64
#  30  PROVEEDOR                 2674 non-null   string
#  31  RUCDETALLEPROVEEDOR       25 non-null     Int64
#  32  DETALLEPROVEEDOR          25 non-null     string
#  33  URLFICHAPROCESO           2676 non-null   string
#  34  RUBROS                    2676 non-null   string
# dtypes: Int64(6), float64(4), string(25)
# memory usage: 747.5 KB
# None

# %% [markdown]
# #### 8-Bono

# %%
## Loading data
fname = os.path.join(PATH, data_path , "8-bonos-covid/Bonos_universo-limpio.csv")
df = pd.read_csv(fname, engine='python', sep=';', header=0, names= ['CodigoHogar', 'Ubigeo','Departamento', 'Provincia','Distrito','Genero','Restriccion','AntiguoPadron',
                                                                         'Discapacidad','AdultoMayor'])
# Loading view
pd.set_option('display.max_columns', 999)

# Inpect the df
df.shape   #Rows = 1 048 575, Cols = 10
df.dtypes
print("-----------Name of columns-----------", "\n", df.columns)
print("-----------Information of dataset----------")
print(df.info(null_counts=True))

# Correccion de valores de variables

# Genero
df['Genero'].values
df.replace({'Genero': {1: "Hombre", 2 : "Mujer"}}, inplace= True)

#Indicador de antiguo padron
df['AntiguoPadron'].values
df.replace({'AntiguoPadron': {1: "Si", 0 : "No"}}, inplace= True)

# Discapacidad
df['AdultoMayor'].values
df.replace({'AdultoMayor': {1: "Si", 0 : "No"}}, inplace= True)

# Adulto mayor
df['Discapacidad'].values
df.replace({'Discapacidad': {1: "Si", 0 : "No"}}, inplace= True)

# Correccion de formato de variables
dfn = df.convert_dtypes()
dfn
dfn.dtypes
print("-----------Name of columns-----------", "\n", df.columns)
print("-----------Information of dataset----------")
print(dfn.info(null_counts=True))

# Saving processed data
fname = os.path.join(PATH, data_output_path , "8-bonos-covid.csv")
dfn.to_csv(fname, index=False)
# Out:
# -----------Name of columns-----------
#  Index(['CodigoHogar', 'Ubigeo', 'Departamento', 'Provincia', 'Distrito',
#        'Genero', 'Restriccion', 'AntiguoPadron', 'Discapacidad',
#        'AdultoMayor'],
#       dtype='object')
# -----------Information of dataset----------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 10 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   CodigoHogar    1048575 non-null  int64
#  1   Ubigeo         1048575 non-null  int64
#  2   Departamento   1048575 non-null  object
#  3   Provincia      1048575 non-null  object
#  4   Distrito       1048438 non-null  object
#  5   Genero         1048574 non-null  float64
#  6   Restriccion    15750 non-null    object
#  7   AntiguoPadron  1048520 non-null  float64
#  8   Discapacidad   1048520 non-null  float64
#  9   AdultoMayor    1048575 non-null  int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 80.0+ MB
# None
# -----------Name of columns-----------
#  Index(['CodigoHogar', 'Ubigeo', 'Departamento', 'Provincia', 'Distrito',
#        'Genero', 'Restriccion', 'AntiguoPadron', 'Discapacidad',
#        'AdultoMayor'],
#       dtype='object')
# -----------Information of dataset----------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 10 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   CodigoHogar    1048575 non-null  Int64
#  1   Ubigeo         1048575 non-null  Int64
#  2   Departamento   1048575 non-null  string
#  3   Provincia      1048575 non-null  string
#  4   Distrito       1048438 non-null  string
#  5   Genero         1048574 non-null  string
#  6   Restriccion    15750 non-null    string
#  7   AntiguoPadron  1048520 non-null  string
#  8   Discapacidad   1048520 non-null  string
#  9   AdultoMayor    1048575 non-null  string
# dtypes: Int64(2), string(8)
# memory usage: 82.0 MB
# None
