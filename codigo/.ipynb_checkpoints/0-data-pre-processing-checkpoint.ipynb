# %% [markdown]
# # Data pre-processing
# ## Raw to tidy matched employer-employee
#
# Created : 22th, March <br>
# Last modified: 24th March <br>
# Author: Joan Jennier Martínez P. (UC Berkeley, California Policy Lab)
#
# **Description**: This script handles the pre processsing of the data received from the Ministry of Labor of Peru.  The goal here is to rearrange a messy dataset into one that is **tidy** (i.e. in the correct format).
#
# - Input: .dta files (12) from the file path "/Users/martinezp_jj/Dropbox/__ Berkeley/10 Spring 2020/__ P1 Banks and Labor/1_Prework/rawdata/envio1819"
# - Output: .csv file (one per year) for statistical analysis
#
# **Comments**:
# The two most important properties of tidy data are:
#
# 1. Each column is a variable.
# 2. Each row is an observation.
#
# Tidy data is easier to work with, because you have a consistent way of referring to variables (as column names) and observations (as row indices). It then becomes easy to manipulate, visualize, and model.
#
# For more on the concept of *tidy* data, read Hadley Wickham's paper [here](http://vita.had.co.nz/papers/tidy-data.html) and [D-Lab data wrangling in R](https://github.com/dlab-berkeley/R-wrang/blob/master/Tutorial.Rmd#L37).

# %% [markdown]
# ### 1. Dataset loading

# %%
from __future__ import with_statement
import os 
import pandas as pd
import numpy as np
import shutil

# Determining working path
PATH = "/Users/martinezp_jj/Dropbox/__Berkeley/10 Spring 2020/__P1 Banks and Labor/1_Prework/"
output_path = "data-build"
data_path = "rawdata/envio1819"
script_path = "scripts"

# Loading data
fname = os.path.join(PATH, data_path , "2018 Meses/Priv_201802.dta")
df = pd.read_stata(fname)

# %%
# Loaded data overview
pd.set_option('display.max_columns', 999)
df
# Out:
#         v_numperiod c_codsexo  n_monperman   d_fecnac v_codcatocu_it  \
# 0            201802         1        850.0 1982-10-01             03
# 1            201802         1        850.0 1986-12-26             03
# 2            201802         2        850.0 1982-11-01             03
# 3            201802         2        935.0 1992-05-04             03
# 4            201802         2        935.0 1984-11-06             03
# ...             ...       ...          ...        ...            ...
# 3337643      201802         1       1500.0 1959-12-01             03
# 3337644      201802         1        850.0 1968-09-14             03
# 3337645      201802         1        850.0 1969-10-27             03
# 3337646      201802         1        850.0 1986-03-31             03
# 3337647      201802         1        850.0 1960-02-10             03
#
#         ubigeo_ok  ubigeo c_tipoadm v_codocupac_it v_codciiu v_codsec  \
# ...

# %%
# Inpect the df
df.shape   #Rows = 3 400 840, Cols = 33
df.dtypes
print("-----------Name of columns-----------", "\n", df.columns)
print("-----------Information of dataset----------")
print(df.info(null_counts=True))

# Most cols are Dtype= object. Need to correct
# Out:
# -----------Name of columns-----------
#  Index(['v_numperiod', 'c_codsexo', 'n_monperman', 'd_fecnac', 'v_codcatocu_it',
#        'ubigeo_ok', 'ubigeo', 'c_tipoadm', 'v_codocupac_it', 'v_codciiu',
#        'v_codsec', 'v_codnivedu_it', 'c_codinsedu_u', 'c_codforsup_u',
#        'c_codcarrer_u', 'c_anioegres_u', 'num_trab', 'd_feciniper_8',
#        'v_codtipcon_it', 'v_estreglabt_it', 'c_codtippre', 'c_codmovfpe_8',
#        'c_codpainac_3', 'c_regpension', 'c_regsalud', 'i_numtothor',
#        'i_numdivila', 'sindicalizado', 'n_estnegcol', 'v_estdiscap_it',
#        'id_empresa', 'id_trabajador', '_merge'],
#       dtype='object')
# -----------Information of dataset----------
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3337648 entries, 0 to 3337647
# Data columns (total 33 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   v_numperiod      3337648 non-null  object
# ...

# %%
# Initial correction on gender variable
df['c_codsexo'].values  #They are integer
df.replace({'c_codsexo': {"1": "Male", "2" : "Female"}}, inplace= True)
df
# Out:
#         v_numperiod c_codsexo  n_monperman   d_fecnac v_codcatocu_it  \
# 0            201802      Male        850.0 1982-10-01             03
# 1            201802      Male        850.0 1986-12-26             03
# 2            201802    Female        850.0 1982-11-01             03
# 3            201802    Female        935.0 1992-05-04             03
# 4            201802    Female        935.0 1984-11-06             03
# ...             ...       ...          ...        ...            ...
# 3337643      201802      Male       1500.0 1959-12-01             03
# 3337644      201802      Male        850.0 1968-09-14             03
# 3337645      201802      Male        850.0 1969-10-27             03
# 3337646      201802      Male        850.0 1986-03-31             03
# 3337647      201802      Male        850.0 1960-02-10             03
#
#         ubigeo_ok  ubigeo c_tipoadm v_codocupac_it v_codciiu v_codsec  \
# ...

# %% [markdown]
# ### 2. Dataframe ready to process

# %%
# Correction of all oter dtypes
dfn = df.convert_dtypes()
dfn

# Inpect the dfn
print("-----------Information Dtypes of dataset----------")
print(dfn.info(null_counts=True))

# In result, no objects anymore
# Out:
# -----------Information Dtypes of dataset----------
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3337648 entries, 0 to 3337647
# Data columns (total 33 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   v_numperiod      3337648 non-null  string
#  1   c_codsexo        3337648 non-null  string
#  2   n_monperman      3337648 non-null  float64
#  3   d_fecnac         3166612 non-null  datetime64[ns]
#  4   v_codcatocu_it   3337648 non-null  string
#  5   ubigeo_ok        3337648 non-null  string
#  6   ubigeo           3337648 non-null  string
#  7   c_tipoadm        3337648 non-null  string
#  8   v_codocupac_it   3337648 non-null  string
#  9   v_codciiu        3337648 non-null  string
#  10  v_codsec         3337648 non-null  string
#  11  v_codnivedu_it   3337648 non-null  string
#  12  c_codinsedu_u    3337648 non-null  string
#  13  c_codforsup_u    3337648 non-null  string
# ...

# %%
# Rename columns
# SEC: Inspired in the Standard Industrial Classification (SIC), in this case is Standard Economic Classification
map_colnames = {'v_numperiod' : 'Month', 'd_fecnac': 'DOB', 'c_codsexo' : 'Gender', 'v_codcatocu_it': 'ISCO2',
                'n_monperman': 'Wage', 'ubigeo_ok': 'WorkerUbigeo', 'ubigeo': 'FirmUbigeo', 'c_tipoadm': 'FirmsAdmin', 
               'v_codocupac_it': 'ISCO6', 'v_codciiu': 'ISCO5', 'v_codsec': 'SEC',
                'v_codnivedu_it' : 'EduLevel', 
                'c_codinsedu_u' : 'EduCod9',
                'c_codforsup_u' : 'HighEdu',
                'c_codcarrer_u' : 'HighEduCod9',
                'c_anioegres_u' : 'HighEduGraduationYr',
                'num_trab' : 'NumWorkers',
                'd_feciniper_8' : 'DateWorkStart',
                'v_codtipcon_it' : 'Contract',
                'v_estreglabt_it': 'LaborLawRegime',
                'c_codtippre':   'WorkerType',           #Pending, check if appropaite to add Retireed
                'c_codmovfpe_8': 'ReasonNonRecord',
                'c_codpainac_3': 'WorkerNationality',
                'c_regpension': 'RetirementLawRegime',
                'c_regsalud':'HealthInsurance',
                'i_numtothor': 'HoursWorked',
                'i_numdivila': 'DaysWorked',
                'sindicalizado': 'Union',
                'n_estnegcol': 'CollectiveNeg',
                'v_estdiscap_it': 'DisabilityStatus',
                'id_empresa': 'FirmID',
                'id_trabajador': 'WorkerID',
                '_merge': 'Merge'}
dfn.rename(columns=map_colnames, inplace=True)
dfn.head(10)
# Out:
#     Month  Gender    Wage        DOB ISCO2 WorkerUbigeo FirmUbigeo FirmsAdmin  \
# 0  201802    Male  850.00 1982-10-01    03       250101     250101          0
# 1  201802    Male  850.00 1986-12-26    03       250101     250101          0
# 2  201802  Female  850.00 1982-11-01    03       250101     250101          0
# 3  201802  Female  935.00 1992-05-04    03       160112     160112          0
# 4  201802  Female  935.00 1984-11-06    03       160112     160112          0
# 5  201802  Female  850.00 1992-05-06    03       160112     160112          0
# 6  201802  Female  935.00 1981-02-28    03       160112     160112          0
# 7  201802  Female  850.00 1988-02-04    03       160112     160112          0
# 8  201802    Male  872.56 1959-07-22    02       250101     250101          0
# 9  201802    Male  850.00 1965-12-06    03       250301     250301          0
#
#     ISCO6 ISCO5 SEC EduLevel EduCod9 HighEdu HighEduCod9 HighEduGraduationYr  \
# 0  252001  9309   O       07
# ...

# %% [markdown]
# ### 3. Encoding columns in correct dtypes
#
# Now, I list the problems that I have found within each variable recoding.
# - There is 17,5285 obs. that do not have "F" neither "M" values, but instead they are unlabeled "  ". This is the same as my STATA pre inspection of the dataset.
# - --merge: In dictionary is stated this variable is for rules of business.
# - n_monperman: What variables of wage exactly? (*Questions for Mr. Ramón Dias (MTPE)*)
#
# <br>
#
# Some notes regarding the recodification in english and coherently with international codes are detailed as follows:
#
# - Categories 11, 12, 13, 14 come from ISOC classification (Wikipedia)[https://en.wikipedia.org/wiki/International_Standard_Classification_of_Occupations#Major_group_1]
# - Categories 21, 22, 23 correspond to Law 30057 of Public Service.
# - **ISOC2 are heavily concentrated on 'employees'. Improvement possbiity by crossing information with other datasets.**
#
# #### 3.1. Worker characteristics

# %%
# Inspection and dtype correction of variables
import datetime as dt

# 'Month'
dfn['Month'].dtypes
dfn['Month'] = dfn['Month'].str.extract(r'(\d{2}$)').astype('int')

# 'Gender'
dfn['Gender'] = dfn['Gender'].replace(" ", np.nan)
dfn.iloc[:,1].describe()
dfn.iloc[:,1].value_counts()

# 'DOB'
dfn['DOB'] = pd.DatetimeIndex(dfn['DOB'])
dfn['DOBMonth'] = dfn['DOB'].dt.month_name()
dfn['DOBYear'] = dfn['DOB'].dt.year.astype('Int64')
dfn['DOBDay'] = dfn['DOB'].dt.day.astype('Int64')

# 'ISOC2'
dfn.iloc[:,4].describe()
dfn.iloc[:,4].value_counts()
#isoc2_dict_SP= {1: "Ejecutivo", 2: "Obrero", 3: "Empleado", 11: "Funcionario", 
#            12: "Profesional", 13: "Técnico", 14: "Auxiliar", 21: "Funcionario público - Ley 30057", 
#            22: "Directivo público - Ley 30057", 23: "Servidor civil de carrera - Ley 30057", 
#            24: "Servidor de actividades complementarias - Ley 30057", 99: "No determinado")
isoc2_dict_EN= {"01": "Managers", "02": "Workers", "03": "Employees", 
            "11": "Chief executives, senior officials and legislators", 
            "12": "Professionals", "13": "Technicians and associate professionals", 
            "14": "Clerical support workers", "21": "Civil servant", 
            "22": "Public director", "23": "Career civil servant", 
            "24": "Public servant of complementary activities", "99": "Undetermined"}
dfn['ISCO2'] = dfn['ISCO2'].map(isoc2_dict_EN)
dfn['ISCO2'] = dfn['ISCO2'].replace(99, np.nan)
dfn['ISCO2'].value_counts()            # Table

# WokerUBIGEO and FirmUbigeo
dfn['WorkerUbigeo'] = pd.to_numeric(dfn['WorkerUbigeo'])
dfn['FirmUbigeo'] = pd.to_numeric(dfn['FirmUbigeo'])

# Generate a variable for Lima
dfn['WorkerLima'] =  ["Province" if (x>=150200 and x<=159999) else ("Metropolitan area" if (x>=150000 and x<=159999)  
                      else "No Lima") for x in dfn['WorkerUbigeo']]
dfn['FirmLima'] =  ["Province" if (x>=150200 and x<=159999) else ("Metropolitan area" if (x>=150000 and x<=159999)  
                      else "No Lima") for x in dfn['FirmUbigeo']]
dfn['WorkerLima'] = dfn['WorkerLima'].convert_dtypes(convert_string= True)
dfn['FirmLima'] = dfn['FirmLima'].convert_dtypes(convert_string= True)

# ISCO
dfn['ISCO6'] = dfn['ISCO6'].replace(" ", np.nan)
dfn['ISCO5'] = dfn['ISCO5'].replace(" ", np.nan)

dfn['ISCO6'] = pd.to_numeric(dfn['ISCO6'], errors='coerce')  #If failed, coerces into NAN
dfn['ISCO5'] = pd.to_numeric(dfn['ISCO5'], errors='coerce')

# Pending labelling

# 'SEC' Standard economic sectors
# StringDtype
sec_dict_SP = {'A' : "Agricultura, ganadería, caza y silvicultura" ,
'B' : "Pesca", 
'C' : "Explotación de minas y canteras",
'D' : "Industrias manufactureras",
'E' : "Suministro de electricidad gas y agua",
'F' : "COnstrucción",
'G' : "Comercio al por mayor y al por menor, rep. vehíc. autom.",
'H' : "Restaurantes y hoteles",
'I' : "Transporte, almacenamiento y comunicaciones",
'J' : "Intermediación financiera",
'K' : "Actividades inmobiliarias, empresariales y de alquiler",
'L' : "Administración pública y defensa",
'M' : "Enseñanza",
'N' : "Servicios sociales y de salud",
'O' : "Otras activ. serv. comunitarios, sociales y personales",
'P' : "Hogares privados con servicio doméstico",
'Q' : "Organizaciones y órganos extraterritoriales"}

sec_dict_EN= {
'A': "Agriculture, livestock, hunting and forestry",
'B': "Fishing",
'C': "Mining and quarrying",
'D': "Manufacturing industries",
'E': "Electricity, gas and water supply",
'F': "Construction",
'G': "Wholesale and retail trade, auto vehicle rep.",
'H': "Restaurants and hotels",
'I': "Transport, storage and communications",
'J': "Financial intermediation",
'K': "Real estate, business and rental activities",
'L': "Public administration and defense",
'M': "Teaching",
'N': "Social and health services",
'O': "Other community, social and personal services activities",
'P': "Private households with domestic service",
'Q': "Organizations and extraterritorial bodies"}
dfn['SEC'] = dfn['SEC'].map(sec_dict_EN)
#dfn['SEC'] = dfn['SEC'].replace("  ", np.nan)
dfn['SEC'] = dfn['SEC'].replace(np.nan, "Undetermined")

# 'EduLevel'
dfn['EduLevel'] = dfn['EduLevel'].replace("0", np.nan)
dfn['EduLevel'] = dfn['EduLevel'].replace("00", np.nan)
dfn['EduLevel'] = dfn['EduLevel'].replace(" ", np.nan)
dfn['EduLevel'] = dfn['EduLevel'].replace("1", "01")


edulevel_dict_SP= {
'01' : "Sin educación formal",
'02' : "Educación especial incompleta",
'03' : "Educación especial completa",
'04' : "Educación primaria incompleta",
'05' : "Educación primaria completa",
'06' : "Educación secundaria incompleta",
'07' : "Educación secundaria completa",
'08' : "Educación técnica incompleta",
'09' : "Educación técnica completa",
'10' : "Educación superior (instituto superior,etc) incompleta",
'11' : "Educación superior (Instituto superior,etc) completa",
'12' : "Educación universitaria incompleta",
'13' : "Educación superior completa",
'14' : "Grado de Bachiller",
'15' : "Titulado",
'16' : "Estudios de maestría incompleta",
'17' : "Estudios de maestría completa",
'18' : "Grado de maestría",
'19' : "Estudios e doctorados incompleto",
'20' : "Estudios de doctorado completo",
'21' : "Grado de doctor",
'99' : "No determinado"}

edulevel_dict_EN= {
'01': "No formal education",
'02': "Incomplete special education",
'03': "Complete special education",
'04': "Incomplete primary education",
'05': "Complete primary education",
'06': "Incomplete secondary education",
'07': "Complete secondary education",
'08': "Incomplete technical education",
'09': "Complete technical education",
'10': "Incomplete higher education (high school, etc.)",
'11': "Higher Education (Higher Institute, etc) complete",
'12': "Incomplete university education",
'13': "Complete higher education",
'14': "Bachelor's degree",
'15': "Professional degree",
'16': "Incomplete masters studies",
'17': "Complete masters studies",
'18': "Masters' degree",
'19': "Incomplete doctoral studies",
'20': "Complete doctoral studies",
'21': "Doctor's degree",
'99': "Not determined"}

dfn['EduLevel'] = dfn['EduLevel'].map(edulevel_dict_EN)

# 'EduCod9'
# 'HighEdu'

# 'HighEduCod9'

# 'HighEduGraduationYr'
dfn['HighEduGraduationYr'] = dfn['HighEduGraduationYr'].replace(" ", np.nan)
dfn['HighEduGraduationYr'] = dfn['HighEduGraduationYr'].replace("9999", np.nan)

dfn['HighEduGraduationYr'] = dfn['HighEduGraduationYr'].convert_dtypes()
dfn['HighEduGraduationYr'] = pd.to_numeric(dfn['HighEduGraduationYr'], errors='coerce').astype(float) #NAN is float

# 'NumWorkers'
# No changes made. No " " or NAN

# 'CatNumWorkers'
dfn['CatNumWorkers'] =  ["1 to 10" if (x>=1 and x<=10) 
                         else ("11 to 100" if (x>=11 and x<=100) 
                          else ("101 to 499" if (x>=101 and x<=499) 
                                else "More than 500")) for x in dfn['NumWorkers']]

# 'DateWorkStart'
# We see 20 'NaT' (missing value for time data)
print(dfn['DateWorkStart'][dfn['DateWorkStart'].isnull()])
# Nothing done for now
# dfn[dfn['DateWorkStart'].isnull()]
# Out:
# 3355      NaT
# 121110    NaT
# 128699    NaT
# 214336    NaT
# 249162    NaT
# 284616    NaT
# 344796    NaT
# 476777    NaT
# 482937    NaT
# 719174    NaT
# 719988    NaT
# 809387    NaT
# 917436    NaT
# 929487    NaT
# 930051    NaT
# 934318    NaT
# 983722    NaT
# 1007776   NaT
# 1128207   NaT
# 1151854   NaT
# 1185741   NaT
# 1189989   NaT
# 1213844   NaT
# 1493651   NaT
# 1506604   NaT
# 1532727   NaT
# 1542933   NaT
# 1570043   NaT
# 1612237   NaT
# 1653286   NaT
# 1806553   NaT
# 1857624   NaT
# 1861715   NaT
# 1889696   NaT
# 1909565   NaT
# 1954378   NaT
# 1985258   NaT
# 2001460   NaT
# 2251917   NaT
# 2329091   NaT
# 2353014   NaT
# 2451182   NaT
# 2738879   NaT
# 2888567   NaT
# 2986089   NaT
# 2997417   NaT
# 3003511   NaT
# 3203232   NaT
# 3211713   NaT
# 3247440   NaT
# 3279810   NaT
# 3304633   NaT
# Name: DateWorkStart, dtype: datetime64[ns]

# %% [markdown]
# Next, I recode the variables that are related to a next set of variables.

# %%
# 'Contract'
dfn['Contract'] = dfn['Contract'].replace(".", np.nan)
dfn['Contract'] = dfn['Contract'].replace(" ", np.nan)
dfn['Contract'] = dfn['Contract'].replace("0", np.nan)
dfn['Contract'] = dfn['Contract'].replace("00", np.nan)

contract_dict_SP= {'01': "A plazo indeterminado (DLeg 728)",
'02': "A tiempo parcial",
'03': "Por inicio o incremento de actividad",
'04': "Por necesidades del mercado",
'05': "Por reconversión empresarial",
'06': "Ocasional",
'07': "De suplencia",
'08': "De emergencia",
'09': "Para obra determinada o servicio específico",
'10': "Intermitente",
'11': "De temporada",
'12': "De exportación no tradicional (DLey 22342)",
'13': "De extranjero-D.Leg. 689",
'14': "Administrativo de servicios (DLeg 1057-CAS)",
'15': "Nombrado (DLeg 276)",
'16': "Serv. Pers. (Régim. carrera)",
'17': "Gerente público (DLeg 1024)",
'18': "A domicilio",
'19': "Futbolistas profesionales",
'20': "Agrario (Ley 27360)",
'21': "Migrante andino decisión 545",
'22': "A plazo indeterminado (Ley 30057)",
'23': "A plazo fijo (Ley 30057)",
'24': "Nombrado - Carreras especiales del sector público",
'25': "Contratado - Carreras especiales del sector público",
'99': "Otros no previsto",
'100': "No determinado"}

contract_dict_EN= {'01': "For an indefinite term",
'02': "Part-time",
'03': "By start or increase of activity",
'04': "Due to market needs",
'05': "For business conversion",
'06': "Occasional",
'07': "Of substitute",
'08': "Emergency",
'09': "For a specific work or specific service",
'10': "Flashing",
'11': "Seasonal",
'12': "Non-traditional export",
'13': "From abroad",
'14': "Administrative services contract (CAS)",
'15': "Named (DLeg 276)",
'16': "Personal Service - Race Regime",
'17': "Public manager (DLeg 1024)",
'18': "At home",
'19': "Professional footballers",
'20': "Agrarian (Law 27360)",
'21': "Andean migrant",
'22': "For an undetermined term (Law 30057)",
'23': "For a fixed term (Law 30057)",
'24': "Named - Special careers in the public sector",
'25': "Hired - Special careers in the public sector",
'99': "Others not foreseen",
'100': "Not determined"}

dfn['Contract'] = dfn['Contract'].map(contract_dict_EN)
dfn['Contract'] = dfn['Contract'].astype('category')

# 'LaborLawRegime'
# dfn['LaborLawRegime'] 
dfn['LaborLawRegime'] = dfn['LaborLawRegime'].replace(" ", np.nan)
dfn['LaborLawRegime'] = dfn['LaborLawRegime'].replace("0", np.nan)
dfn['LaborLawRegime'] = dfn['LaborLawRegime'].replace(".", np.nan)
dfn['LaborLawRegime'] = dfn['LaborLawRegime'].replace('1', '01')

laborlawregime_dict_SP= {'01': "Privado general-Decreto legislativo N° 728",
'02': "Público general - Decreto legislativo N° 276",
'03': "Profesorado - Ley N° 24029",
'04': "Magisterio - Ley N° 29062",
'05': "Docentes universitarios - Ley N° 23733",
'06': "Profesionales de la salud Ley N° 23536",
'07': "Técnicos y auxiliares asist. de la salud - Ley N° 28561",
'08': "SERUM - Ley N° 23330",
'09': "Jueces - Carrera judicial - Ley N° 29277",
'10': "Fiscales - D. Leg. N° 052",
'11': "Servicio diplomático de la república - Ley N° 28091",
'12': "Militares",
'13': "Policía Nacional del Perú - Ley N° 27238",
'14': "Especial Ger. Públicos Decreto Legislativo N° 1024",
'15': "Contrato Administratico de Servicios (CAS) - D. Leg. N° 1057",
'16': "Microempresa D. Leg. 1086",
'17': "Pequeña empresa D. Leg. 1086",
'18': "Agrario ley 27360",
'19': "Exportación no tradicional D. Ley 22342",
'20': "Mineros",
'21': "Construcción civil",
'22': "Público general servicio civil - Ley 30057",
'23': "Magisterio - Ley 29944",
'24': "Policía Nacional del Perú D. Leg. 1149",
'25': "Servidores penitenciarios - Ley 29709",
'99': "Otros no previstos",
'999': "No determinado"}

laborlawregime_dict_EN= {'01': "Private General (DLeg 728)",
'02': "General public (DLeg 276)",
'03': "Teachers (Law 24029)",
'04': "Teaching (Law 29062",
'05': "University teachers (Law 23733)",
'06': "Health professionals (Law 23536)",
'07': "Healthcare technicians and auxiliaries (Law 28561)",
'08': "SERUM (Law 23330)",
'09': "Judges, Judicial career (Law 29277)",
'10': "Prosecutors (DLeg 052)",
'11': "Diplomatic service of the republic (Law 28091)",
'12': "Military",
'13': "National Police of Peru (Law 27238)",
'14': "Special Public Managers (DLeg 1024)",
'15': "Administrative Services Contract (CAS) (DLeg 10570)",
'16': "Microempresa (DLeg 1086)",
'17': "Small business (DLeg 1086)",
'18': "Agrarian (Law 27360)",
'19': "Non-traditional export (DLaw 22342)",
'20': "Miners",
'21': "Civil construction",
'22': "General public civil service (DLaw 30057)",
'23': "Teaching (DLaw 29944)",
'24': "National Police of Peru (DLeg 1149)",
'25': "Prison servers (DLeg 29709)",
'99': "Others not foreseen",
'999': "Not determined"}

dfn['LaborLawRegime'] = dfn['LaborLawRegime'].map(laborlawregime_dict_EN)
dfn['LaborLawRegime'] = dfn['LaborLawRegime'].astype('category')

# 'WorkerType'
# Note: Public-server specialist and 'Position of trust' are in 'Undetermined' category
dfn['WorkerType'] = dfn['WorkerType'].replace(" ", np.nan)

workertype_dict_SP= {19: "Ejecutivo" ,
20: "Obrero" ,
21: "Empleado" ,
22: "Trabajador portuario - Ley 27866" ,
23: "Practicante SENATI - Dec. ley 20151" ,
24: "Pensionista o cesante" ,
25: "Beneficiario de transf. directa ex PESCADRES" ,
26: "Pensionista - Ley 28320",
27: "Construcción civil",
28: "Piloto y copiloto de aviación comercial",
29: "Marítimo, fluvial o lacustre",
30: "Periodista",
31: "Trabajador de la industria de cuero",
32: "Minero de mina de socavón",
36: "Trabajador pesquero",
37: "Minero de tajo abierto",
38: "Minero de industria minera metalúrgica y/o siderúrgica",
39: "Trabajador pesquero - Ley 30003",
56: "Artista - Ley 28131",
64: "Agrario dependiente - Ley 27360",
65: "Trabajador actividad acuícola - Ley 27460",
66: "Pescador y procesador artesanal indeendiente - Ley 27177",
67: "Régimen especial D. Leg. 1057 - CAS",
71: "Conductor de microempresa REMYPE - D. Leg. 1086",
73: "Socio de cooperativa agraria - Ley N° 29972",
82: "Funcionario público",
83: "Empleado de confianza",
84: "Servidor público - Directivo superior",
85: "Servidor público - Ejecutivo",
86: "Servidor público - Especialista",
87: "Servidor público - De apoyo",
88: "Personal de la adm. pública - asignación especial - D.U.126-2001",
89: "Personal de las fuerzas aramadas y policiales (1)",
90: "Gerentes públicos - D. Leg. 1024",
91: "Miembros de otros reg. especiales del sector público",
92: "Funcionario público - Ley 30057",
93: "Directivo público - Ley 30057",
94: "Servidor civil de carrera - Ley 30057",
95: "Servidor de actividades complementarias - Ley 30057",
96: "Magisterio - Ley 29944",
98: "Persona que genera ingresos de cuarta - quinta categoría"}

workertype_dict_EN= {'19': "Executive",
'20': "Worker",
'21': "Employee",
'22': "Dock worker (Law 27866)",
'23': "SENATI Practitioner (Dec. Law 20151)",
'24': "Pensioner or unemployed",
'25': "Beneficiary of direct transfer (ex-PESCADPRES)",
'26': "Pensioner (Law 28320)",
'27': "Civil construction",
'28': "Commercial aviation pilot, co-pilot",
'29': "Maritime, river or lake",
'30': "Journalist",
'31': "Leather Industry Worker",
'32': "Pit mine miner",
'36': "Fishing worker",
'37': "Open pit miner",
'38': "Miner of metallurgical/steel mining industry",
'39': "Fishing worker (Law 30003)",
'56': "Artist (Law 28131)",
'64': "Dependent Agrarian (Law 27360)",
'65': "Aquaculture activity worker (Law 27460)",
'66': "Fisherman and independent artisan processor (Law 27177)",
'67': "Special Regime (CAS) (DLeg 1057)",
'71': "REMYPE microenterprise driver - Leg. 1086",
'73': "Member of the agrarian cooperative - Law No. 29972",
'82': "Public official",
'83': "Trusted Employee",
'84': "Public servant - Senior manager",
'85': "Public servant - Executive",
'86': "Public servant - Specialist",
'87': "Public servant - Support",
'88': "Public administration personnel (Special assignment) (D.U.126-2001)",
'89': "Staff of the armed forces and the police",
'90': "Public managers (D. Leg. 1024)",
'91': "Members of other special regs of the public sector",
'92': "Public official (Law 30057)",
'93': "Public manager (Law 30057)",
'94': "Civil career servant (Law 30057)",
'95': "Server of complementary activities (Law 30057)",
'96': "Teaching (Law 29944)",
'98': "Person generating income from fourth (5th category)"}

dfn['WorkerType'] = dfn['WorkerType'].map(workertype_dict_EN)
dfn['WorkerType'] = dfn['WorkerType'].astype('category')


# 'ReasonNonRecord'
dfn['ReasonNonRecord'] = dfn['ReasonNonRecord'].replace(" ", np.nan)
dfn['ReasonNonRecord'] = dfn['ReasonNonRecord'].replace(".", np.nan)

reasonnonrecord_dict_SP= {'01': "Renuncia" ,
'02': "Renuncia con incentivos",
'03': "Despido o destitución",
'04': "Cese colectivo" ,
'05': "Jubilación",
'06': "Invalidez absoluta permanente" ,
'07': "Terminación de la obra o servicio, cumplimiento condición resolutoria o vencimiento del plazo" ,
'08': "Mutuo disenso" ,
'09': "Fallecimiento" ,
'10': "Suspensión de la pensión 1/" ,
'11': "Reasignación servidor de la administración pública 2/" ,
'12': "Permuta servidor de la administración pública 2/" ,
'13': "Transferencia servidor de la administración pública 2/" ,
'14': "Baja por suceción en posición del empleador" ,
'15': "Extinción o liquidación del empleador" ,
'16': "Otros motivos de caducidad de la pensión 1/" ,
'17': "No se inició la relación laboral o prestación efectiva de servicios" ,
'18': "Límite de edad 70 años" ,
'19': "Otras causales régimen público general servicio civil - Ley 30057" ,
'20': "Inhabilitación para el ejercicio profesional o de la función pública por más de tres meses - Ley 30057" ,
'99': "Sin vínculo laboral - habilitado para PDT PLAME" ,
'100': "No determinado"}

reasonnonrecord_dict_EN= {'01': "Resignation",
'02': "Resignation with incentives",
'03': "Dismissal, layoff",
'04': "Collective layoff",
'05': "Retirement",
'06': "Permanent absolute disability",
'07': "Completion of the work or service, compliance with resolution condition or expiration of term",
'08': "Mutual dissent",
'09': "Death",
'10': "Suspension of retirement plan",
'11': "Reassignment of public administration server",
'12': "Swap public administration server",
'13': "Transfer public administration server",
'14': "Termination due to succession in the employer's position",
'15': "Termination or liquidation of the employer",
'16': "Other reasons for retirement plan expiration",
'17': "Labor relationship or effective provision of services did not start",
'18': "Age limit (70 yo)",
'19': "Other causes in general public civil service regime (Law 30057)",
'20': "Disqualification for professional practice or public service for more than 3 months - Law 30057",
'99': "No working link - enabled for PDT PLAME",
'100': "Not determined"}

dfn['ReasonNonRecord'] = dfn['ReasonNonRecord'].map(reasonnonrecord_dict_EN)
dfn['ReasonNonRecord'] = dfn['ReasonNonRecord'].astype('category')

# %% [markdown]
# In the variable `ReasonNonRecord` consider the following:<br>
# -1/ Solo aplica a pensionista<br>
# -2/ No aplica a empleadores del sector privado
#
# *Pending: Define the private, retired and service supplier category"*

# %%
# 'WorkerNationality'
dfn['WorkerNationality'] = dfn['WorkerNationality'].replace('0000', np.nan)
dfn['WorkerNationality'] = dfn['WorkerNationality'].replace(".", np.nan)

workernationality_dict_SP= {
'9001' : "Bouvet Island",
'9002' : "Cote D Ivoire"  ,
'9003' : "Falkland Islands (Malvinas)",
'9004' : "France, Metropolitan",
'9005' : "French Southern Territories",
'9006' : "Heard and Mc Donald Islands",
'9007' : "Mayote",
'9008' : "South Georgia and the South Sandwich Islands",
'9009' : "Svalbard and Jan Mayen Islands",
'9010' : "United States Minor Outlying Islands",
'9013' : "Afganistan",
'9017' : "Albania",
'9019' : "Alderney",
'9023' : "Alemania",
'9026' : "Armenia",
'9027' : "Aruba",
'9028' : "Ascencion",
'9029' : "Bosnia-Herzegovina",
'9031' : "Burkina Faso",
'9037' : "Andorra",
'9040' : "Angola",
'9041' : "Anguila",
'9043' : "Antigua y Barbuda",
'9047' : "Antillas Holandesas",
'9053' : "Arabia Saudita",
'9059' : "Argelia",
'9063' : "Argentina",
'9069' : "Australia",
'9072' : "Austria",
'9074' : "Azerbaijan",
'9077' : "Bahamas",
'9080' : "Bahrein",
'9081' : "Bangla Desh",
'9083' : "Barbados",
'9087' : "Bélgica",
'9088' : "Belice",
'9090' : "Bermudas",
'9091' : "Belarus",
'9093' : "Myanmar",
'9097' : "Bolivia" ,
'9101' : "Botswana" ,
'9105' : "Brasil" , 
'9108' : "Brunei Darussalam" ,
'9111' : "Bulgaria" ,
'9115' : "Burundi" ,
'9119' : "Butan" ,
'9127' : "Cabo Verde" ,
'9137' : "Islas Caimán" ,
'9141' : "Camboya" ,
'9145' : "República Unida del Camerún" ,
'9147' : "Campione D Talia" ,
'9149' : "Canadá" ,
'9155' : "Islas Canal (Normandas)" ,
'9157' : "Canton y Enderburry" ,
'9159' : "Santa Sede" ,
'9165' : "Islas Cocos (Keeling)" ,
'9169' : "Colombia" ,
'9173' : "Comoras" ,
'9177' : "Congo" ,
'9183' : "Islas Cook" ,
'9187' : "República Popular Democrática de Corea (Norte)" ,
'9190' : "Republica de Corea (Sur)" ,
'9193' : "Costa de Marfil" ,
'9196' : "Costa Rica" ,
'9198' : "Croacia" ,
'9199' : "Cuba" ,
'9203' : "Chad" ,
'9207' : "Checoslovaquia" ,
'9211' : "Chile" ,
'9215' : "China" ,
'9218' : "Taiwan (Formosa)" ,
'9221' : "Chipre" ,
'9229' : "Benin" ,
'9232' : "Dinamarca" ,
'9235' : "Dominica" ,
'9239' : "Ecuador" ,
'9240' : "Egipto" ,
'9242' : "El Salvador" ,
'9243' : "Eritrea" ,
'9244' : "Emiratos Árabes Unidos" ,
'9245' : "España" ,
'9246' : "Eslovaquia" ,
'9247' : "Eslovenia" ,
'9249' : "Estados Unidos" ,
'9251' : "Estonia" ,
'9253' : "Etiopia" ,
'9259' : "Islas Feroe" ,
'9267' : "Filipinas" ,
'9271' : "Finlandia" ,
'9281' : "Francia" ,
'9285' : "Gabon" ,
'9286' : "Gaza y Jerico" ,
'9287' : "Georgia" ,
'9289' : "Ghana" ,
'9293' : "Gibraltar" ,
'9297' : "Granada" ,
'9301' : "Grecia" ,
'9305' : "Groenlandia" ,
'9309' : "Guadalupe" , 
'9313' : "Guam" ,
'9317' : "Guatemala" ,
'9325' : "Guayana Francesa" ,
'9327' : "Guernsey" ,
'9329' : "Guinea" ,
'9331' : "Guinea Ecuatorial" ,
'9334' : "Guinea - Bissau" ,
'9337' : "Guyana" ,
'9341' : "Haiti" ,
'9345' : "Honduras" ,
'9348' : "Honduras Británicas" ,
'9351' : "Hong Kong" ,
'9355' : "Hungría" ,
'9361' : "India" ,
'9365' : "Indonesia" ,
'9369' : "Irak" ,
'9372' : "República Islámica del Irán" ,
'9375' : "Irlanda (Eire)" ,
'9377' : "Isla Azores" ,
'9378' : "Isla del Man" ,
'9379' : "Islandia" ,
'9380' : "Islas Canarias" ,
'9381' : "Islas de Christmas" ,
'9382' : "Islas Qeshm" ,
'9383' : "Israel" ,
'9386' : "Italia" , 
'9391' : "Jamaica" ,
'9395' : "Islas Jonston" ,
'9399' : "Japón" ,
'9401' : "Jersey" ,
'9403' : "Jordania" ,
'9406' : "Kazajstan" ,
'9410' : "Kenia" ,
'9411' : "Kiribati" ,
'9412' : "Kirguizistan" ,
'9413' : "Kuwait" ,
'9418' : "Labun" ,
'9420' : "República Popular Democrática de Laos" ,
'9426' : "Lesotho" ,
'9429' : "Letonia" ,
'9431' : "Líbano" ,
'9434' : "Liberia" ,
'9438' : "Libia" ,
'9440' : "Liechtenstein" ,
'9443' : "Lituania" ,
'9445' : "Luxemburgo" ,
'9447' : "Macao" ,
'9448' : "Macedonia" ,
'9450' : "Madagascar" ,
'9453' : "Madeira" ,
'9455' : "Malaysia" ,
'9458' : "Malawi" ,
'9461' : "Maldivas" ,
'9464' : "Mali" ,
'9467' : "Malta" ,
'9469' : "Islas Marianas del Norte" ,
'9472' : "Islas Marshall" ,
'9474' : "Marruecos" ,
'9477' : "Martinica" ,
'9485' : "Mauricio" ,
'9488' : "Mauritania" ,
'9493' : "México" ,
'9494' : "Estados Federados de Micronesia" ,
'9495' : "Islas Midway" ,
'9496' : "Moldavia" ,
'9497' : "Mongolia" ,
'9498' : "Monaco" ,
'9501' : "Isla Monserrat" ,
'9505' : "Mozambique" ,
'9507' : "Namibia" ,
'9508' : "Nauru" ,
'9511' : "Isla Navidad (Christmas)" ,
'9517' : "Nepal" ,
'9521' : "Nicaragua" ,
'9525' : "Niger" , 
'9528' : "Nigeria" ,
'9531' : "Isla Niue" ,
'9535' : "Isla Norfolk" ,
'9538' : "Noruega" ,
'9542' : "Nueva Caledonia" ,
'9545' : "Papuasia Nueva Guinea" ,
'9548' : "Nueva Zelanda" ,
'9551' : "Vanuatu" ,
'9556' : "Oman" ,
'9566' : "Islas del Pacífico" ,
'9573' : "Países Bajos" ,
'9576' : "Pakistán" ,
'9578' : "Islas Palau" ,
'9579' : "Territorio Autónomo de Palestina" ,
'9580' : "Panamá" ,
'9586' : "Paraguay" ,
'9589' : "Perú" ,
'9593' : "Isla Pitcairn" ,
'9599' : "Polinesia Francesa" ,
'9603' : "Polonia" ,
'9607' : "Portugal" ,
'9611' : "Puerto Rico" ,
'9618' : "Qatar" ,
'9628' : "Reino Unido" ,
'9629' : "Escocia" ,
'9633' : "República Árabe Unida" ,
'9640' : "República Centroafricana" ,
'9644' : "República Checa" ,
'9645' : "República de Swazilandia" ,
'9646' : "República de Tunez" ,
'9647' : "República Dominicana" ,
'9660' : "Reunion" ,
'9665' : "Zimbabwe" ,
'9670' : "Rumania" ,
'9675' : "Ruanda" ,
'9676' : "Rusia" ,
'9677' : "Islas Salomon" ,
'9685' : "Sahara Occidental" ,
'9687' : "Samoa Occidental" ,
'9690' : "Samoa Norteamericana" ,
'9695' : "San Cristobal y Nieves" ,
'9697' : "San Marino" ,
'9700' : "San Pedro y Miquelon" ,
'9705' : "San Vicente y Las Granadinas" ,
'9710' : "Santa Elena" ,
'9715' : "Santa Lucía" ,
'9720' : "Santo Tome y Principe" ,
'9728' : "Senegal" ,
'9731' : "Seychelles" ,
'9735' : "Sierra Leona" ,
'9741' : "Singapur" ,
'9744' : "República Árabe de Siria" ,
'9748' : "Somalia" ,
'9750' : "Sri Lanka" ,
'9756' : "República de Sudáfrica" ,
'9759' : "Sudan" ,
'9764' : "Suecia" ,
'9767' : "Suiza" ,
'9770' : "Surinam" ,
'9773' : "Sawsilandia" ,
'9774' : "Tadjikistan" ,
'9776' : "Tailandia" ,
'9780' : "República Unida de Tanzania" ,
'9783' : "Djibouti" ,
'9786' : "Territorio Antártico Británico" ,
'9787' : "Territorio Británico del Océano Índico" ,
'9788' : "Timor del Este" ,
'9800' : "Togo" ,
'9805' : "Tokelau" ,
'9810' : "Tonga" ,
'9815' : "Trinidad y Tobago" ,
'9816' : "Tristan Da Cunha" ,
'9820' : "Tunicia" ,
'9823' : "Islas Turcas y Caicos" ,
'9825' : "Turkmenistan" ,
'9827' : "Turquía" ,
'9828' : "Tuvalu" ,
'9830' : "Ucrania" ,
'9833' : "Uganda" ,
'9840' : "URSS" ,
'9845' : "Uruguay" ,
'9847' : "Uzbekistan" ,
'9850' : "Venezuela" ,
'9855' : "Viet Nam" ,
'9858' : "Vietnam (Del Norte)" ,
'9863' : "Islas Vírgenes (Británicas)" ,
'9866' : "Islas Vírgenes (Norteamericanas)" ,
'9870' : "Fiji" ,
'9873' : "Isla Wake" ,
'9875' : "Islas Wallis y Fortuna" ,
'9880' : "Yemen" ,
'9885' : "Yugoslavia" ,
'9888' : "Zaire" ,
'9890' : "Zambia" ,
'9895' : "Zona del Canal de Panamá" ,
'9896' : "Zona Libre Ostrava" ,
'9897' : "Zona Neutral (Palestina)" ,
'10000': "No determinado/Otros países"}

#'9011': "Other countries or places",
# '9011' : "Otros países o lugares",
# Recoded as NA

workernationality_dict_EN = {
'9001': "Bouvet Island",
'9002': "Cote D Ivoire",
'9003': "Falkland Islands (Malvinas)",
'9004': "France, metropolitan",
'9005': "French Southern Territories",
'9006': "Heard and Mc Donald Islands",
'9007': "Mayote",
'9008': "South Georgia and the South Sandwich Islands",
'9009': "Svalbard and Jan Mayen Islands",
'9010': "United States Minor Outlying Islands",
'9013': "Afghanistan",
'9017': "Albania",
'9019': "Alderney",
'9023': "Germany",
'9026': "Armenia",
'9027': "Aruba",
'9028': "Ascension",
'9029': "Bosnia-Herzegovina",
'9031': "Burkina Faso",
'9037': "Andorra",
'9040': "Angola",
'9041': "Anguilla",
'9043': "Antigua and Barbuda",
'9047': "Netherlands Antilles",
'9053': "Saudi Arabia",
'9059': "Algeria",
'9063': "Argentina",
'9069': "Australia",
'9072': "Austria",
'9074': "Azerbaijan",
'9077': "Bahamas",
'9080': "Bahrain",
'9081': "Bangla Desh",
'9083': "Barbados",
'9087': "Belgium",
'9088': "Belize",
'9090': "Bermuda",
'9091': "Belarus",
'9093': "Myanmar",
'9097': "Bolivia",
'9101': "Botswana",
'9105': "Brazil",
'9108': "Brunei Darussalam",
'9111': "Bulgaria",
'9115': "Burundi",
'9119': "Butan",
'9127': "Cape Verde",
'9137': "Cayman Islands",
'9141': "Cambodia",
'9145': "United Republic of Cameroon",
'9147': "Campione D Talia",
'9149': "Canada",
'9155': "Channel Islands (Normans)",
'9157': "Canton and Enderburry",
'9159': "Holy See",
'9165': "Cocos (Keeling) Islands",
'9169': "Colombia",
'9173': "Comoros",
'9177': "Congo",
'9183': "Cook Islands",
'9187': "Democratic People's Republic of Korea (North)",
'9190': "Republic of Korea (South)",
'9193': "Ivory Coast",
'9196': "Costa Rica",
'9198': "Croatia",
'9199': "Cuba",
'9203': "Chad",
'9207': "Czechoslovakia",
'9211': "Chile",
'9215': "China",
'9218': "Taiwan (Formosa)",
'9221': "Cyprus",
'9229': "Benin",
'9232': "Denmark",
'9235': "Dominica",
'9239': "Ecuador",
'9240': "Egypt",
'9242': "El Salvador",
'9243': "Eritrea",
'9244': "United Arab Emirates",
'9245': "Spain",
'9246': "Slovakia",
'9247': "Slovenia",
'9249': "United States",
'9251': "Estonia",
'9253': "Ethiopia",
'9259': "Faroe Islands",
'9267': "Philippines",
'9271': "Finland",
'9281': "France",
'9285': "Gabon",
'9286': "Gaza and Jericho",
'9287': "Georgia",
'9289': "Ghana",
'9293': "Gibraltar",
'9297': "Granada",
'9301': "Greece",
'9305': "Greenland",
'9309': "Guadalupe",
'9313': "Guam",
'9317': "Guatemala",
'9325': "French Guiana",
'9327': "Guernsey",
'9329': "Guinea",
'9331': "Equatorial Guinea",
'9334': "Guinea - Bissau",
'9337': "Guyana",
'9341': "Haiti",
'9345': "Honduras",
'9348': "British Honduras",
'9351': "Hong Kong",
'9355': "Hungary",
'9361': "India",
'9365': "Indonesia",
'9369': "Iraq",
'9372': "Islamic Republic of Iran",
'9375': "Ireland (Eire)",
'9377': "Isla Azores",
'9378': "Isle of Man",
'9379': "Iceland",
'9380': "Canary Islands",
'9381': "Christmas Islands",
'9382': "Qeshm Islands",
'9383': "Israel",
'9386': "Italy",
'9391': "Jamaica",
'9395': "Jonston Islands",
'9399': "Japan",
'9401': "Jersey",
'9403': "Jordan",
'9406': "Kazakhstan",
'9410': "Kenya",
'9411': "Kiribati",
'9412': "Kyrgyzstan",
'9413': "Kuwait",
'9418': "Labun",
'9420': "Democratic People's Republic of Laos",
'9426': "Lesotho",
'9429': "Latvia",
'9431': "Lebanon",
'9434': "Liberia",
'9438': "Libya",
'9440': "Liechtenstein",
'9443': "Lithuania",
'9445': "Luxembourg",
'9447': "Macao",
'9448': "Macedonia",
'9450': "Madagascar",
'9453': "Madeira",
'9455': "Malaysia",
'9458': "Malawi",
'9461': "Maldives",
'9464': "Mali",
'9467': "Malta",
'9469': "Northern Mariana Islands",
'9472': "Marshall Islands",
'9474': "Morocco",
'9477': "Martinique",
'9485': "Mauritius",
'9488': "Mauritania",
'9493': "Mexico",
'9494': "Federated States of Micronesia",
'9495': "Midway Islands",
'9496': "Moldova",
'9497': "Mongolia",
'9498': "Monaco",
'9501': "Isla Monserrat",
'9505': "Mozambique",
'9507': "Namibia",
'9508': "Nauru",
'9511': "Christmas Island (Christmas)",
'9517': "Nepal",
'9521': "Nicaragua",
'9525': "Niger",
'9528': "Nigeria",
'9531': "Niue Island",
'9535': "Norfolk Island",
'9538': "Norway",
'9542': "New Caledonia",
'9545': "Papua New Guinea",
'9548': "New Zealand",
'9551': "Vanuatu",
'9556': "Oman",
'9566': "Pacific Islands",
'9573': "Netherlands",
'9576': "Pakistan",
'9578': "Palau Islands",
'9579': "Autonomous Territory of Palestine",
'9580': "Panama",
'9586': "Paraguay",
'9589': "Peru",
'9593': "Pitcairn Island",
'9599': "French Polynesia",
'9603': "Polonia",
'9607': "Portugal",
'9611': "Puerto Rico",
'9618': "Qatar",
'9628': "United Kingdom",
'9629': "Scotland",
'9633': "United Arab Republic",
'9640': "Central African Republic",
'9644': "Czech Republic",
'9645': "Republic of Swaziland",
'9646': "Republic of Tunisia",
'9647': "Dominican Republic",
'9660': "Reunion",
'9665': "Zimbabwe",
'9670': "Romania",
'9675': "Rwanda",
'9676': "Russia",
'9677': "Solomon Islands",
'9685': "Western Sahara",
'9687': "Western Samoa",
'9690': "American Samoa",
'9695': "Saint Kitts and Nevis",
'9697': "San Marino",
'9700': "Saint Pierre and Miquelon",
'9705': "Saint Vincent and the Grenadines",
'9710': "Santa Elena",
'9715': "Saint Lucia",
'9720': "Santo Tome y Principe",
'9728': "Senegal",
'9731': "Seychelles",
'9735': "Sierra Leone",
'9741': "Singapore",
'9744': "Arab Republic of Syria",
'9748': "Somalia",
'9750': "Sri Lanka",
'9756': "Republic of South Africa",
'9759': "Sudan",
'9764': "Sweden",
'9767': "Switzerland",
'9770': "Suriname",
'9773': "Sawsilandia",
'9774': "Tadjikistan",
'9776': "Thailand",
'9780': "United Republic of Tanzania",
'9783': "Djibouti",
'9786': "British Antarctic Territory",
'9787': "British Indian Ocean Territory",
'9788': "East Timor",
'9800': "Togo",
'9805': "Tokelau",
'9810': "Tonga",
'9815': "Trinidad and Tobago",
'9816': "Tristan Da Cunha",
'9820': "Tunisia",
'9823': "Turks and Caicos Islands",
'9825': "Turkmenistan",
'9827': "Turkey",
'9828': "Tuvalu",
'9830': "Ukraine",
'9833': "Uganda",
'9840': "USSR",
'9845': "Uruguay",
'9847': "Uzbekistan",
'9850': "Venezuela",
'9855': "Viet Nam",
'9858': "Vietnam (North)",
'9863': "Virgin Islands (British)",
'9866': "Virgin Islands (North American)",
'9870': "Fiji",
'9873': "Wake Island",
'9875': "Wallis and Fortuna Islands",
'9880': "Yemen",
'9885': "Yugoslavia",
'9888': "Zaire",
'9890': "Zambia",
'9895': "Panama Canal Zone",
'9896': "Ostrava Free Zone",
'9897': "Neutral Zone (Palestine)",
'10000': "Not determined / Other countries"}

dfn['WorkerNationality'] = dfn['WorkerNationality'].map(workernationality_dict_EN)
dfn['WorkerNationality'] = dfn['WorkerNationality'].astype('category')
# Out:
# Afghanistan                    1
# Albania                        1
# Alderney                       1
# Algeria                        4
# Andorra                        1
#                             ...
# Venezuela                   8043
# Viet Nam                     128
# Vietnam (North)                2
# Virgin Islands (British)       3
# Yugoslavia                    19
# Name: WorkerNationality, Length: 138, dtype: int64

# %% [markdown]
# The variables are reated to pension regimes an retirements.

# %%
# 'RetirementLawRegime'
dfn['RetirementLawRegime'] = dfn['RetirementLawRegime'].replace(" ", np.nan)

retirementlawregine_dict_SP = {
'02' : "Sistema Nacional de Pensiones (ONP) (DL 19990)",
'03' : "DLey 20530",
'09' : "Caja de beneficios de seguridad social del pescador",
'10' : "Caja de pensiones militar",
'11' : "Caja de pensiones policial",
'12' : "Otros regímenes pensionarios",
'13' : "Régimen del servicio diplomático de la república",
'14' : "Sistema nacional de pensiones (independientes) (Ley 29903)",
'15' : "Régimen especial de pensiones-pesqueros (Ley 30003)",
'16' : "Transferencia directa ex pesc (Ley 30003)",
'21' : "Sistema privado de pensiones Integra",
'22' : "Sistema privado de pensiones Horizonte",
'23' : "Sistema privado de pensiones Profuturo",
'24' : "Sistema privado de pensiones Prima",
'25' : "SPP Habitat",
'98' : "Pendiente de elección de régimen pensionario",
'99' : "Sin régimen pensionario/No aplica",
'999' : "No determinado"}  

retirementlawregine_dict_EN = {
'02': "National Pension System (ONP) (DL 19990)",
'03': "DLey 20530",
'09': "Fisherman's Social Security Benefit Fund",
'10': "Military pension fund",
'11': "Police pension fund",
'12': "Other pension schemes",
'13': "Regime of the diplomatic service of the republic",
'14': "National (independent) pension system (Law 29903)",
'15': "Special pension-fishing regime (Law 30003)",
'16': "Direct transfer ex pesc (Law 30003)",
'21': "Integra private pension system",
'22': "Horizonte private pension system",
'23': "Profuturo private pension system",
'24': "Prima private pension system",
'25': "SPP Habitat",
'98': "Pending pension system election",
'99': "Without pension scheme / Does not apply",
'999': "Not determined"}   

dfn['RetirementLawRegime'] = dfn['RetirementLawRegime'].map(retirementlawregine_dict_EN)
dfn['RetirementLawRegime'] = dfn['RetirementLawRegime'].astype('category')
dfn['RetirementLawRegime'].value_counts().sort_index()
# Out:
# DLey 20530                                        648
# Fisherman's Social Security Benefit Fund           75
# Horizonte private pension system                60252
# Integra private pension system                 569057
# Military pension fund                              95
# National Pension System (ONP) (DL 19990)      1044155
# Other pension schemes                               1
# Pending pension system election                   620
# Police pension fund                                58
# Prima private pension system                   687983
# Profuturo private pension system               422697
# SPP Habitat                                    415034
# Special pension-fishing regime (Law 30003)       2563
# Without pension scheme / Does not apply        134011
# Name: RetirementLawRegime, dtype: int64

# %%
# 'HealthInsurance',
dfn['HealthInsurance'] = dfn['HealthInsurance'].replace(".", np.nan)
dfn['HealthInsurance'] = dfn['HealthInsurance'].replace(" ", np.nan)

healthinsurance_dict_SP = {
'00' : "EsSalud regular (Exclusivamente)",
'01': "EsSalud Regular y EPS/Serv. propios",
'02': "EsSalud trabajadores pesqueros",
'03': "EsSalud trabajadores pesqueros y EPS (Serv. propios)",
'04': "EsSalud agrario/acuícola",
'05': "EsSalud pensionistas",
'20': "Sanidad de FFAA y policiales 1/",
'21': "SIS - Microempresa 2/",
'99': "No determinado"}  

healthinsurance_dict_EN = {
'00' : "EsSalud regular (Exclusivamente)",
'01': "EsSalud Regular and EPS or private insurance",
'02': "EsSalud fishing workers",
'03': "EsSalud fishing workers and EPS (own services)",
'04': "EsSalud agricultures",
'05': "EsSalud retirees",
'20': "Health of the armed forces and police",
'21': "SIS - Microenterprise",
'99': "Not determined"
}   

dfn['HealthInsurance'] = dfn['HealthInsurance'].map(healthinsurance_dict_EN)
dfn['HealthInsurance'] = dfn['HealthInsurance'].astype('category')

# %%
# 'DisabilityStatus'
dfn['DisabilityStatus'] = ["Yes" if (x=='1') else ("No" if x== '0'  else 'Unknown') for x in dfn['DisabilityStatus']]
dfn['DisabilityStatus'] = dfn['DisabilityStatus'].replace("Unknown", np.nan)
dfn['DisabilityStatus'] = dfn['DisabilityStatus'].astype('category')

# 'Union'
dfn['Union'] = ["Yes" if (x=='SI' and x!=np.nan) else 
                ("No" if (x== "NO" and x!=np.nan) else x) for x in dfn['Union']]
dfn['Union'] = dfn['Union'].astype('category')


# 'CollectiveNeg'
dfn['CollectiveNeg'] = ["Yes" if (x>=1 and x!=np.nan) else 
                        ("No" if (x==0 and x!=np.nan) else x) for x in dfn['CollectiveNeg']]
dfn['CollectiveNeg'] = dfn['CollectiveNeg'].astype('category')

# %% [markdown]
# #### 3.2. Wages

# %%
# Wage
dfn.iloc[:,3].describe()
dfn.iloc[:,3].value_counts()
dfn['DOB'] = pd.to_datetime(dfn['DOB'], format='%d-%m-%Y', 
                            errors='coerce', infer_datetime_format=True, exact="strict")

# %% [markdown]
# #### 3.3. Worked days

# %%
import matplotlib.pyplot as plt
plt.close('all')

print(dfn['DaysWorked'].dtypes)
print(dfn['DaysWorked'].isnull().sum())
print(dfn['DaysWorked'].value_counts().sort_index())
print(dfn['DaysWorked'].describe())
dfn['DaysWorked'].hist()


#---------------------------------------
#.isnull().sum()
#.value_counts().sort_index()
#fillna("Missing")

#print(dfn['DateWorkStart'].isnull().sum())

#---------------------------------------

#dfn['WorkerNationality'].dtypes


#dfn.describe()
# Out:
# Int64
# 47
# 1       23484
# 2       10612
# 3       14234
# 4        5042
# 5        7688
# 6        7978
# 7        9996
# 8        9340
# 9       11852
# 10      19074
# 11       4991
# 12       6745
# 13      10466
# 14      12496
# 15      14978
# 16      11230
# 17      17872
# 18       4378
# 19       8918
# 20       8843
# 21       9958
# 22       9186
# 23      10567
# 24      20578
# 25       4233
# 26       6025
# 27       9058
# 28    2997412
# 29        141
# 30      10763
# 31      39409
# 33          1
# 36          2
# 37         12
# 41          2
# 42          3
# 43          2
# 45          1
# 50          2
# 51          1
# 55          5
# 56         21
# 62          1
# 80          1
# Name: DaysWorked, dtype: Int64
# count    3.337601e+06
# mean     2.677076e+01
# std      4.756205e+00
# min      1.000000e+00
# 25%      2.800000e+01
# 50%      2.800000e+01
# 75%      2.800000e+01
# max      8.000000e+01
# Name: DaysWorked, dtype: float64

# %% [markdown]
# #### 3.4. Worked hours
# Una exploración de las horas trabajadas senala que hay outliers (>200) y varios registros registran 0 horas trabajadas (117 189 obs).

# %%
print(dfn['HoursWorked'].dtypes)
print(dfn['HoursWorked'].isnull().sum())
print(dfn['HoursWorked'].value_counts().sort_index())
print(dfn['HoursWorked'].describe())

dfn['HoursWorked'].hist()
# Out:
# Int64
# 47
# 0      101473
# 1        2715
# 2         576
# 3        1050
# 4        2184
#         ...
# 594         1
# 595         1
# 600         1
# 668         1
# 850         1
# Name: HoursWorked, Length: 559, dtype: Int64
# count    3.337601e+06
# mean     1.832284e+02
# std      7.063194e+01
# min      0.000000e+00
# 25%      1.600000e+02
# 50%      1.920000e+02
# 75%      2.250000e+02
# max      8.500000e+02
# Name: HoursWorked, dtype: float64

# %% [markdown]
# ### 4. Long vs. wide formatting
#
# I will now manipulate the dataset to make it a bit more tidy.

# %%
dfn.columns
dfn = dfn[['Month','WorkerID', 'FirmID', 'FirmsAdmin', 'NumWorkers', 'Gender', 'DOB', 'DOBMonth',
           'DOBYear', 'DOBDay', 'WorkerNationality', 'WorkerUbigeo', 'WorkerLima', 
           'FirmUbigeo','FirmLima', 'EduLevel', 'EduCod9', 'HighEdu','HighEduCod9',
           'HighEduGraduationYr', 'ISCO2', 'ISCO6', 'ISCO5',
           'SEC', 'DateWorkStart','Contract', 'LaborLawRegime', 'WorkerType', 'ReasonNonRecord',
           'RetirementLawRegime', 'HealthInsurance','DisabilityStatus', 'Union', 'CollectiveNeg',
           'HoursWorked', 'DaysWorked', 'Wage','CatNumWorkers', 'Merge']]

# %%
dfn
# Out:
#          Month  WorkerID       FirmID FirmsAdmin  NumWorkers  Gender  \
# 0            2  22924344  00001000387          0           2    Male
# 1            2  54364078  00001000387          0           2    Male
# 2            2  71254885  00001003334          0           1  Female
# 3            2  08014614  00001006981          0           5  Female
# 4            2  23314623  00001006981          0           5  Female
# ...        ...       ...          ...        ...         ...     ...
# 3337643      2  87120645  97811233007          0           5    Male
# 3337644      2  29450294  97831595771          0           2    Male
# 3337645      2  70401836  97831595771          0           2    Male
# 3337646      2  65184456  97911551526          0           1    Male
# 3337647      2  79310110  97921680739          0           1    Male
#
#                DOB   DOBMonth  DOBYear  DOBDay WorkerNationality  \
# 0       1982-10-01    October     1982       1              Peru
# ...

# %% [markdown]
# I check the duplicated observations and then the unique values per colum.

# %%
# Based on all columns
print('Number of duplicated obs.: ', dfn.duplicated().sum())

# Based on KEYS columns
print('Number of duplicated obs. based on KEYS: ', 
      dfn.duplicated(subset= ['WorkerID', 'FirmID', 'Gender', 'DOB', 'WorkerNationality']).sum())
# Out:
# Number of duplicated obs.:  0
# Number of duplicated obs. based on KEYS:  0

# %% [markdown]
# Inspecting the unique values of each column.

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

list = dfn.columns
for x in list: 
    print(x,': ', dfn[x].unique())
# Out:
# Month :  [2]
# WorkerID :  <StringArray>
# ['22924344', '54364078', '71254885', '08014614', '23314623', '52927426',
#  '61204489', '84384288', '50810936', '10210267',
#  ...
#  '86960606', '33684241', '64164521', '78154460', '85074027', '87120645',
#  '29450294', '70401836', '65184456', '79310110']
# Length: 3274592, dtype: string
# FirmID :  <StringArray>
# ['00001000387', '00001003334', '00001006981', '00001013750', '00001018176',
#  '00001021040', '00001022656', '00001028206', '00001040676', '00001040705',
#  ...
#  '97641978688', '97711065249', '97711240784', '97711745182', '97721468972',
#  '97721961171', '97811233007', '97831595771', '97911551526', '97921680739']
# Length: 290582, dtype: string
# FirmsAdmin :  <StringArray>
# ['0']
# Length: 1, dtype: string
# NumWorkers :  <IntegerArray>
# [   2,    1,    5,    3,    4,    7,    6,    9,   14,   11,
#  ...
#   368, 1067, 1958,  909,  468, 1795, 2419, 2835, 8197,  761]
# Length: 1117, dtype: Int16
# Gender :  <StringArray>
# ...

# %% [markdown]
# Variables identified to have NAN, nan, "<NA>" are:<br>
# - Month [Good]
# - 'WorkerID' [Good]
# - 'FirmID' [Good]
# - 'FirmsAdmin': All '0' in STATA [Solved]
# - 'NumWorkers' [Good]
# - 'Gender': Corrected in code up [Solved]
# - DOB, DOBMonth, DOBYear,DOBDay, have all missing values where DOB has a missing value [Solved].

# %%
#dfn['DOBMonth'].value_counts().sort_index()
#dfn[dfn['DOBMonth'].isnull()]
print('Nan in DOB month: ', dfn['DOBMonth'].isnull().sum())
print('Nan in DOB day: ', dfn['DOBDay'].isnull().sum())
print('Nan in DOB year: ', dfn['DOBYear'].isnull().sum())
# Out:
# Nan in DOB month:  171036
# Nan in DOB day:  171036
# Nan in DOB year:  171036

# %% [markdown]
# - Worker Nationality: Missing code for country '9275' [Unsolved]
# - 'WorkerUbigeo', 'WorkerLima': [Good]
# - 'FirmUbigeo', 'FirmLima': [Good]
# - EduLevel: compared to STATA, equivalent [Solved]
# - 'EduCod9': No recode dictionary [Unsolved]
# - 'HighEduGraduationYr', Nan= 2868519, cross with the higher education workers [Unsolved]
# - HighEdu: cross with education column [Unsolved]
# - HighEduGraduationYr: NAN same as in STATA file. 9999 value was recorded as nan lines above. [Solved]
# - 'ISCO2', 'ISCO6', 'ISCO5', 'SEC', 'DateWorkStart'
# - Contract: dictionary modified dictionary lines above. [Solved]
# - LaborLawRegime: dictionary modified dictionary lines above. [Solved]
# - 'WorkerType': No NAN [Solved]
# - 'ReasonNonRecord': Nan value was recorded as nan lines above. [Solved]
# - 'RetirementLawRegime': compared to STATA, equivalent [Solved]
# - 'HealthInsurance': dictionary modified dictionary lines above [solved]
# - DisabilityStatus: compared to STATA, equivalent [Solved]
# - 'Union': compared to STATA, equivalent [Solved]
# - 'CollectiveNeg': compared to STATA, equivalent [Solved]
# - 'HoursWorked': compared to STATA, equivalent [Solved]
# - DaysWorked:  compared to STATA, equivalent [Solved]
# - Wage: compared to STATA, equivalent [Solved]
# - 'CatNumWorkers'
# - 'Merge': non determined colum. Ask [Solved]

# %%
#dfn['HighEduGraduationYr'] = dfn['HighEduGraduationYr'].replace("9999", np.nan)
dfn['HoursWorked'].value_counts(dropna=False).sort_index()
#dfn[dfn['WorkerNationality'].isnull()]
# Out:
# 0      101473
# 1        2715
# 2         576
# 3        1050
# 4        2184
#         ...
# 595         1
# 600         1
# 668         1
# 850         1
# NaN        47
# Name: HoursWorked, Length: 560, dtype: Int64

# %%
dfn.columns
# Out:
# Index(['Month', 'WorkerID', 'FirmID', 'FirmsAdmin', 'NumWorkers', 'Gender',
#        'DOB', 'DOBMonth', 'DOBYear', 'DOBDay', 'WorkerNationality',
#        'WorkerUbigeo', 'WorkerLima', 'FirmUbigeo', 'FirmLima', 'EduLevel',
#        'EduCod9', 'HighEdu', 'HighEduCod9', 'HighEduGraduationYr', 'ISCO2',
#        'ISCO6', 'ISCO5', 'SEC', 'DateWorkStart', 'Contract', 'LaborLawRegime',
#        'WorkerType', 'ReasonNonRecord', 'RetirementLawRegime',
#        'HealthInsurance', 'DisabilityStatus', 'Union', 'CollectiveNeg',
#        'HoursWorked', 'DaysWorked', 'Wage', 'CatNumWorkers', 'Merge'],
#       dtype='object')
